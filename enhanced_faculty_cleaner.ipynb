# %% [markdown]
# # Welcome to Colab!
#
# ## Explore the Gemini API
# The Gemini API gives you access to Gemini models created by Google DeepMind. Gemini models are built from the ground up to be multimodal, so you can reason seamlessly across text, images, code, and audio.
#
# **How to get started?**
# *  Go to [Google AI Studio](https://aistudio.google.com/) and log in with your Google account.
# *  [Create an API key](https://aistudio.google.com/app/apikey).
# * Use a quickstart for [Python](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started.ipynb), or call the REST API using [curl](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/rest/Prompting_REST.ipynb).
#
# **Discover Gemini's advanced capabilities**
# *  Play with Gemini [multimodal outputs](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Image-out.ipynb), mixing text and images in an iterative way.
# *  Discover the [multimodal Live API](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started_LiveAPI.ipynb ) (demo [here](https://aistudio.google.com/live)).
# *  Learn how to [analyze images and detect items in your pictures](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Spatial_understanding.ipynb") using Gemini (bonus, there's a [3D version](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Spatial_understanding_3d.ipynb) as well!).
# *  Unlock the power of [Gemini thinking model](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started_thinking.ipynb), capable of solving complex task with its inner thoughts.
#
# **Explore complex use cases**
# *  Use [Gemini grounding capabilities](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Search_grounding_for_research_report.ipynb) to create a report on a company based on what the model can find on internet.
# *  Extract [invoices and form data from PDF](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Pdf_structured_outputs_on_invoices_and_forms.ipynb) in a structured way.
# *  Create [illustrations based on a whole book](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Book_illustration.ipynb) using Gemini large context window and Imagen.
#
# To learn more, check out the [Gemini cookbook](https://github.com/google-gemini/cookbook) or visit the [Gemini API documentation](https://ai.google.dev/docs/).

# %%
import os
import re
import json
from typing import List, Dict, Any, Optional, Tuple
from qdrant_client import QdrantClient
from qdrant_client.models import (
    Distance, VectorParams, PointStruct, Filter,
    FieldCondition, MatchValue
)
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.schema import Document
import uuid
from datetime import datetime
from collections import defaultdict, Counter
import logging

# Configure logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)
if not logger.handlers:
    handler = logging.StreamHandler()
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    handler.setFormatter(formatter)
    logger.addHandler(handler)
    logger.setLevel(logging.INFO)

class EnhancedFacultyDataCleaner:
    def __init__(self, qdrant_url: str, api_key: str, collection_name: str):
        self.client = QdrantClient(url=qdrant_url, api_key=api_key)
        self.collection_name = collection_name
        self.text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=500,
            chunk_overlap=50,
            separators=["\n\n", "\n", ". ", ", ", " "]
        )

        # Enhanced patterns based on snapshot analysis
        self.faculty_patterns = {
            'basic_entry': r'(\d+)\s+([A-Z\s]+?)\s+(\d+)\s+(Assistant Professor|Associate Professor|Professor|Lecturer)\s+(Male|Female)\s+(Ph\.?\s?D\.?|M\.?\s?Tech|B\.?\s?Tech|M\.?\s?Sc|B\.?\s?Sc|LLM)\s+(\d+)\s+(Yes|No)\s+(\d{2}-\d{2}-\d{4})',
            'pipe_separated': r'(\d+)\s*\|\s*([A-Z\s]+?)\s*\|\s*(\d+)\s*\|\s*(Assistant Professor|Associate Professor|Professor|Lecturer)\s*\|\s*(Male|Female)\s*\|\s*(Ph\.?\s?D\.?|M\.?\s?Tech|B\.?\s?Tech|M\.?\s?Sc|B\.?\s?Sc|LLM)\s*\|\s*(\d+)\s*\|\s*(Yes|No)\s*\|\s*(\d{2}-\d{2}-\d{4})',
            'structured_with_name': r'Name:\s*([A-Za-z\s]+?)\s*\|\s*Designation:\s*([^|]+)\s*\|\s*Gender:\s*([^|]+)\s*\|\s*Qualification:\s*([^|]+)'
        }

        # Location standardization from snapshot
        self.location_mappings = {
            'aligarh': {'city': 'Aligarh', 'state': 'Uttar Pradesh', 'region': 'North India'},
            'delhi': {'city': 'Delhi', 'state': 'Delhi', 'region': 'North India'},
            'mumbai': {'city': 'Mumbai', 'state': 'Maharashtra', 'region': 'West India'},
            'kolkata': {'city': 'Kolkata', 'state': 'West Bengal', 'region': 'East India'},
            'chennai': {'city': 'Chennai', 'state': 'Tamil Nadu', 'region': 'South India'},
            'bangalore': {'city': 'Bangalore', 'state': 'Karnataka', 'region': 'South India'},
            'hyderabad': {'city': 'Hyderabad', 'state': 'Telangana', 'region': 'South India'},
        }

        # Qualification standardization
        self.qualification_mappings = {
            'ph d': 'Ph.D', 'phd': 'Ph.D', 'ph.d': 'Ph.D', 'ph.d.': 'Ph.D',
            'm tech': 'M.Tech', 'm.tech': 'M.Tech', 'mtech': 'M.Tech',
            'b tech': 'B.Tech', 'b.tech': 'B.Tech', 'btech': 'B.Tech',
            'm sc': 'M.Sc', 'm.sc': 'M.Sc', 'msc': 'M.Sc',
            'b sc': 'B.Sc', 'b.sc': 'B.Sc', 'bsc': 'B.Sc',
            'llm': 'LLM', 'l.l.m': 'LLM', 'l.l.m.': 'LLM'
        }

        # Designation standardization
        self.designation_mappings = {
            'assistant': 'Assistant Professor',
            'associate': 'Associate Professor',
            'professor': 'Professor',
            'lecturer': 'Lecturer'
        }

        # Statistics tracking
        self.processing_stats = {
            'total_processed': 0,
            'successfully_parsed': 0,
            'improved_points': 0,
            'deleted_points': 0,
            'faculty_records_found': 0,
            'designation_distribution': defaultdict(int),
            'qualification_distribution': defaultdict(int),
            'processing_errors': []
        }

    def fetch_faculty_data_optimized(self) -> List[Dict[str, Any]]:
        """Optimized faculty data fetching using payload filtering"""
        logger.info("Fetching faculty data with optimized filters...")

        try:
            # Use scroll with filters to get faculty data more efficiently
            faculty_points = []
            offset = None

            while True:
                points, next_offset = self.client.scroll(
                    collection_name=self.collection_name,
                    scroll_filter=Filter(
                        should=[
                            FieldCondition(
                                key="content_type",
                                match=MatchValue(value="faculty")
                            ),
                            FieldCondition(
                                key="chunk_type",
                                match=MatchValue(value="faculty")
                            ),
                            FieldCondition(
                                key="category",
                                match=MatchValue(value="Faculty")
                            )
                        ]
                    ),
                    limit=100,
                    offset=offset,
                    with_payload=True,
                    with_vectors=True
                )



                for point in points:
                    if self._is_faculty_data_enhanced(point.payload):
                        faculty_points.append({
                            'id': point.id,
                            'payload': point.payload,
                            'vector': point.vector
                        })

                if next_offset is None:
                    break
                offset = next_offset

            logger.info(f"Found {len(faculty_points)} faculty data points")
            return faculty_points

        except Exception as e:
            logger.error(f"Error fetching data: {e}")
            # Fallback to original method
            return self._fetch_faculty_data_fallback()

    def _fetch_faculty_data_fallback(self) -> List[Dict[str, Any]]:
        """Fallback method for fetching faculty data"""
        logger.info("Using fallback method for data fetching...")

        scroll_result = self.client.scroll(
            collection_name=self.collection_name,
            limit=1000,
            with_payload=True,
            with_vectors=True
        )

        faculty_points = []
        for point in scroll_result[0]:
            if self._is_faculty_data_enhanced(point.payload):
                faculty_points.append({
                    'id': point.id,
                    'payload': point.payload,
                    'vector': point.vector
                })

        return faculty_points

    def _is_faculty_data_enhanced(self, payload: Dict[str, Any]) -> bool:
        """Enhanced faculty data detection using snapshot insights"""
        content = payload.get('content', '').lower()
        title = payload.get('title', '').lower()
        content_type = payload.get('content_type', '').lower()
        category = payload.get('category', '').lower()
        chunk_type = payload.get('chunk_type', '').lower()

        # Primary indicators from snapshot
        if content_type == 'faculty' or category == 'faculty' or chunk_type == 'faculty':
            return True

        # Secondary indicators
        faculty_keywords = [
            'faculty', 'professor', 'assistant professor', 'associate professor',
            'lecturer', 'phd', 'ph.d', 'ph d', 'male', 'female', 'department',
            'designation', 'qualification', 'joining', 'experience'
        ]

        # Pattern-based detection
        pattern_indicators = [
            r'\d+\s+[A-Z\s]+\s+\d+\s+(Assistant Professor|Associate Professor|Professor)',
            r'Name:\s*[A-Za-z\s]+\s*\|\s*Designation:',
            r'(Male|Female)\s+(Ph\.?\s?D\.?|M\.?\s?Tech)',
            r'\d{2}-\d{2}-\d{4}'  # Date pattern
        ]

        keyword_matches = sum(1 for keyword in faculty_keywords if keyword in content or keyword in title)
        pattern_matches = sum(1 for pattern in pattern_indicators if re.search(pattern, content, re.IGNORECASE))

        return keyword_matches >= 3 or pattern_matches >= 2

    def parse_faculty_entry_enhanced(self, text: str, metadata: Dict[str, Any]) -> List[Dict[str, Any]]:
        """Enhanced parsing with multiple pattern matching"""
        faculty_records = []

        # Try different parsing strategies
        for pattern_name, pattern in self.faculty_patterns.items():
            matches = re.findall(pattern, text, re.IGNORECASE | re.MULTILINE)

            if matches:
                logger.info(f"Using pattern '{pattern_name}' - found {len(matches)} matches")

                for match in matches:
                    if pattern_name == 'structured_with_name':
                        record = self._parse_structured_match(match, metadata)
                    else:
                        record = self._parse_standard_match(match, metadata)

                    if record and self._validate_faculty_record(record):
                        faculty_records.append(record)
                break

        # If no patterns matched, try alternative parsing
        if not faculty_records:
            faculty_records = self._parse_alternative_methods(text, metadata)

        # Clean and enhance records
        faculty_records = self._clean_and_enhance_records(faculty_records, metadata)

        self.processing_stats['faculty_records_found'] += len(faculty_records)
        return faculty_records

    def _parse_standard_match(self, match: Tuple, metadata: Dict[str, Any]) -> Dict[str, Any]:
        """Parse standard faculty match pattern"""
        try:
            if len(match) >= 9:
                record = {
                    'id': match[0].strip(),
                    'name': self._clean_name(match[1]),
                    'age': match[2].strip(),
                    'designation': match[3].strip(),
                    'gender': match[4].strip(),
                    'qualification': match[5].strip(),
                    'experience': match[6].strip(),
                    'phd_status': match[7].strip(),
                    'joining_date': match[8].strip()
                }

                # Add metadata
                record.update(self._extract_metadata_info(metadata))
                return record
        except Exception as e:
            logger.error(f"Error parsing standard match: {e}")

        return {}

    def _parse_structured_match(self, match: Tuple, metadata: Dict[str, Any]) -> Dict[str, Any]:
        """Parse structured faculty match pattern"""
        try:
            record = {
                'name': self._clean_name(match[0]),
                'designation': match[1].strip(),
                'gender': match[2].strip(),
                'qualification': match[3].strip()
            }

            # Add metadata
            record.update(self._extract_metadata_info(metadata))
            return record
        except Exception as e:
            logger.error(f"Error parsing structured match: {e}")

        return {}

    def _parse_alternative_methods(self, text: str, metadata: Dict[str, Any]) -> List[Dict[str, Any]]:
        """Alternative parsing methods for edge cases"""
        faculty_records = []

        # Method 1: Line-by-line parsing
        lines = [line.strip() for line in text.split('\n') if line.strip()]

        for line in lines:
            if self._contains_faculty_indicators(line):
                record = self._extract_faculty_from_line(line, metadata)
                if record:
                    faculty_records.append(record)

        # Method 2: Chunk-based parsing for dense text
        if not faculty_records and len(text) > 500:
            chunks = self._split_dense_text(text)
            for chunk in chunks:
                record = self._extract_faculty_from_chunk(chunk, metadata)
                if record:
                    faculty_records.append(record)

        return faculty_records

    def _clean_and_enhance_records(self, records: List[Dict[str, Any]], metadata: Dict[str, Any]) -> List[Dict[str, Any]]:
        """Clean and enhance faculty records with standardization"""
        cleaned_records = []

        for record in records:
            # Skip invalid records
            if not self._validate_faculty_record(record):
                continue

            # Standardize fields
            record = self._standardize_record_fields(record)

            # Add computed fields
            record = self._add_computed_fields(record, metadata)

            # Update statistics
            self._update_processing_stats(record)

            cleaned_records.append(record)

        return cleaned_records

    def _standardize_record_fields(self, record: Dict[str, Any]) -> Dict[str, Any]:
        """Standardize record fields using mappings"""
        # Standardize qualification
        if 'qualification' in record:
            qual_lower = record['qualification'].lower().strip()
            record['qualification'] = self.qualification_mappings.get(qual_lower, record['qualification'])

        # Standardize designation
        if 'designation' in record:
            des_lower = record['designation'].lower().strip()
            record['designation'] = self.designation_mappings.get(des_lower, record['designation'])

        # Standardize gender
        if 'gender' in record:
            record['gender'] = record['gender'].capitalize()

        # Clean and validate experience
        if 'experience' in record:
            record['experience'] = self._calculate_realistic_experience(record)

        return record

    def _add_computed_fields(self, record: Dict[str, Any], metadata: Dict[str, Any]) -> Dict[str, Any]:
        """Add computed fields based on metadata and analysis"""
        # Add career stage
        record['career_stage'] = self._determine_career_stage(record)

        # Add seniority score
        record['seniority_score'] = self._calculate_seniority_score(record)

        # Add location info from metadata
        if 'city' in metadata:
            record['city'] = metadata['city']
        if 'state' in metadata:
            record['state'] = metadata['state']
        if 'location' in metadata:
            record['region'] = metadata['location']

        # Add academic year info
        if 'year' in metadata:
            record['data_year'] = metadata['year']

        return record

    def _determine_career_stage(self, record: Dict[str, Any]) -> str:
        """Determine career stage based on designation and experience"""
        designation = record.get('designation', '').lower()
        experience = record.get('experience', '0')

        try:
            exp_years = int(experience) if experience.isdigit() else 0
        except:
            exp_years = 0

        if 'assistant' in designation:
            return 'Early Career' if exp_years < 5 else 'Mid Career'
        elif 'associate' in designation:
            return 'Mid Career' if exp_years < 15 else 'Senior Career'
        elif 'professor' in designation:
            return 'Senior Career' if exp_years < 20 else 'Distinguished Career'
        else:
            return 'Unknown'

    def _calculate_seniority_score(self, record: Dict[str, Any]) -> int:
        """Calculate seniority score for ranking"""
        score = 0

        # Designation points
        designation_points = {
            'Assistant Professor': 1,
            'Associate Professor': 2,
            'Professor': 3,
            'Lecturer': 0
        }
        score += designation_points.get(record.get('designation', ''), 0) * 30

        # Experience points
        try:
            experience = int(record.get('experience', '0')) if record.get('experience', '0').isdigit() else 0
            score += min(experience, 40)  # Cap at 40 years
        except:
            pass

        # Qualification points
        qualification_points = {
            'Ph.D': 20,
            'M.Tech': 15,
            'M.Sc': 10,
            'B.Tech': 5,
            'B.Sc': 2,
            'LLM': 15
        }
        score += qualification_points.get(record.get('qualification', ''), 0)

        return score

    def _calculate_realistic_experience(self, record: Dict[str, Any]) -> str:
        """Calculate realistic experience based on joining date"""
        experience = record.get('experience', '0')
        joining_date = record.get('joining_date', '')

        if not joining_date:
            return experience

        try:
            # Parse joining date
            day, month, year = joining_date.split('-')
            join_year = int(year)
            current_year = datetime.now().year

            # Calculate years from joining
            calculated_exp = current_year - join_year

            # Validate and adjust
            if calculated_exp < 0:
                return '0'
            elif calculated_exp > 50:
                return '50+'  # Cap unrealistic values
            else:
                return str(calculated_exp)

        except Exception:
            return experience

    def _validate_faculty_record(self, record: Dict[str, Any]) -> bool:
        """Validate faculty record for completeness and accuracy"""
        # Must have name and designation
        if not record.get('name') or not record.get('designation'):
            return False

        # Name validation
        name = record.get('name', '').strip()
        if len(name) < 2 or name.lower() in ['assistant', 'associate', 'professor', 'lecturer']:
            return False

        # Designation validation
        designation = record.get('designation', '').strip()
        valid_designations = ['Assistant Professor', 'Associate Professor', 'Professor', 'Lecturer']
        if designation not in valid_designations:
            return False

        return True

    def _extract_metadata_info(self, metadata: Dict[str, Any]) -> Dict[str, Any]:
        """Extract relevant metadata information"""
        extracted = {}

        # Location info
        if 'city' in metadata:
            extracted['city'] = metadata['city']
        if 'state' in metadata:
            extracted['state'] = metadata['state']
        if 'location' in metadata:
            extracted['region'] = metadata['location']

        # Academic info
        if 'year' in metadata:
            extracted['data_year'] = metadata['year']
        if 'file_production_year' in metadata:
            extracted['file_year'] = metadata['file_production_year']

        return extracted

    def _clean_name(self, name: str) -> str:
        """Clean and standardize faculty name"""
        # Remove extra whitespace and capitalize properly
        name = ' '.join(name.split())

        # Handle special cases
        name = re.sub(r'\s+', ' ', name)  # Multiple spaces to single space
        name = name.title()  # Proper capitalization

        return name.strip()

    def _contains_faculty_indicators(self, line: str) -> bool:
        """Check if line contains faculty indicators"""
        indicators = [
            'professor', 'lecturer', 'male', 'female', 'phd', 'ph.d',
            'assistant', 'associate', 'faculty', 'department'
        ]

        line_lower = line.lower()
        return any(indicator in line_lower for indicator in indicators)

    def _extract_faculty_from_line(self, line: str, metadata: Dict[str, Any]) -> Optional[Dict[str, Any]]:
        """Extract faculty information from a single line"""
        # Implementation for line-based extraction
        # This is a simplified version - can be enhanced based on specific patterns

        record = {}

        # Extract basic information using regex
        name_match = re.search(r'([A-Z][a-z]+(?:\s+[A-Z][a-z]+)*)', line)
        if name_match:
            record['name'] = name_match.group(1)

        designation_match = re.search(r'(Assistant Professor|Associate Professor|Professor|Lecturer)', line, re.IGNORECASE)
        if designation_match:
            record['designation'] = designation_match.group(1)

        gender_match = re.search(r'(Male|Female)', line, re.IGNORECASE)
        if gender_match:
            record['gender'] = gender_match.group(1)

        if len(record) >= 2:  # At least name and designation
            record.update(self._extract_metadata_info(metadata))
            return record

        return None

    def _split_dense_text(self, text: str) -> List[str]:
        """Split dense text into manageable chunks"""
        # Split by common delimiters
        chunks = re.split(r'(?:\n|;|\|{2,})', text)
        return [chunk.strip() for chunk in chunks if len(chunk.strip()) > 20]

    def _extract_faculty_from_chunk(self, chunk: str, metadata: Dict[str, Any]) -> Optional[Dict[str, Any]]:
        """Extract faculty information from a text chunk"""
        # Similar to line extraction but for larger chunks
        if self._contains_faculty_indicators(chunk):
            return self._extract_faculty_from_line(chunk, metadata)
        return None

    def _update_processing_stats(self, record: Dict[str, Any]):
        """Update processing statistics"""
        if 'designation' in record:
            self.processing_stats['designation_distribution'][record['designation']] += 1
        if 'qualification' in record:
            self.processing_stats['qualification_distribution'][record['qualification']] += 1

    def create_enhanced_content(self, faculty_records: List[Dict[str, Any]]) -> str:
        """Create enhanced structured content with better formatting"""
        if not faculty_records:
            return ""

        # Sort by seniority score for better organization
        sorted_records = sorted(faculty_records, key=lambda x: x.get('seniority_score', 0), reverse=True)

        if len(sorted_records) == 1:
            return self._format_single_faculty(sorted_records[0])
        else:
            return self._format_multiple_faculty(sorted_records)

    def _format_single_faculty(self, record: Dict[str, Any]) -> str:
        """Format single faculty member with comprehensive details"""
        parts = []

        # Basic information
        if record.get('name'):
            parts.append(f"Faculty Name: {record['name']}")
        if record.get('designation'):
            parts.append(f"Position: {record['designation']}")
        if record.get('gender'):
            parts.append(f"Gender: {record['gender']}")
        if record.get('qualification'):
            parts.append(f"Highest Qualification: {record['qualification']}")

        # Experience and career info
        if record.get('experience'):
            exp_text = f"{record['experience']} years" if record['experience'].isdigit() else record['experience']
            parts.append(f"Teaching Experience: {exp_text}")
        if record.get('career_stage'):
            parts.append(f"Career Stage: {record['career_stage']}")

        # Administrative info
        if record.get('phd_status'):
            parts.append(f"PhD Status: {record['phd_status']}")
        if record.get('joining_date'):
            parts.append(f"Date of Joining: {record['joining_date']}")

        # Location info
        location_parts = []
        if record.get('city'):
            location_parts.append(record['city'])
        if record.get('state'):
            location_parts.append(record['state'])
        if location_parts:
            parts.append(f"Location: {', '.join(location_parts)}")

        return " | ".join(parts)

    def _format_multiple_faculty(self, records: List[Dict[str, Any]]) -> str:
        """Format multiple faculty members with organized structure"""
        content_parts = []

        for i, record in enumerate(records, 1):
            faculty_info = []

            # Essential information
            if record.get('name'):
                faculty_info.append(f"Name: {record['name']}")
            if record.get('designation'):
                faculty_info.append(f"Position: {record['designation']}")
            if record.get('qualification'):
                faculty_info.append(f"Qualification: {record['qualification']}")

            # Experience and career
            if record.get('experience'):
                exp_text = record['experience']
                if exp_text.isdigit():
                    exp_text = f"{exp_text} years"
                faculty_info.append(f"Experience: {exp_text}")
            if record.get('career_stage'):
                faculty_info.append(f"Career Stage: {record['career_stage']}")

            # Administrative info
            if record.get('joining_date'):
                faculty_info.append(f"Joined: {record['joining_date']}")

            if faculty_info:
                content_parts.append(f"Faculty {i}: {' | '.join(faculty_info)}")

        return "\n\n".join(content_parts)

    def create_intelligent_title(self, faculty_records: List[Dict[str, Any]], metadata: Dict[str, Any]) -> str:
        """Create intelligent title with context awareness"""
        if not faculty_records:
            return metadata.get('title', 'Faculty Information')

        # Get location context
        location_context = ""
        if metadata.get('city') and metadata.get('state'):
            location_context = f" - {metadata['city']}, {metadata['state']}"
        elif metadata.get('city'):
            location_context = f" - {metadata['city']}"

        if len(faculty_records) == 1:
            record = faculty_records[0]
            name = record.get('name', 'Faculty Member')
            designation = record.get('designation', 'Faculty')
            career_stage = record.get('career_stage', '')

            title = f"Faculty Profile: {name}, {designation}"
            if career_stage:
                title += f" ({career_stage})"
            title += location_context

            return title
        else:
            # Multiple faculty analysis
            total = len(faculty_records)
            designation_counts = Counter(record.get('designation', 'Unknown') for record in faculty_records)

            # Create descriptive title
            if len(designation_counts) == 1:
                designation = list(designation_counts.keys())[0]
                title = f"Faculty Directory: {total} {designation}{'s' if total > 1 else ''}"
            else:
                # Show distribution
                top_designations = designation_counts.most_common(2)
                desc_parts = []
                for des, count in top_designations:
                    desc_parts.append(f"{count} {des}{'s' if count > 1 else ''}")

                if len(desc_parts) == 1:
                    title = f"Faculty Directory: {desc_parts[0]}"
                else:
                    title = f"Faculty Directory: {' | '.join(desc_parts)}"

                if len(designation_counts) > 2:
                    title += f" | +{len(designation_counts) - 2} more"

            title += location_context
            return title

    def process_and_update_collection_enhanced(self):
        """Enhanced main processing method with better error handling and statistics"""
        logger.info("Starting enhanced faculty data cleaning process...")

        # Fetch faculty data with optimization
        faculty_points = self.fetch_faculty_data_optimized()

        if not faculty_points:
            logger.warning("No faculty data found to process")
            return

        updated_points = []
        points_to_delete = []

        for point_data in faculty_points:

            self.processing_stats['total_processed'] +=1
            try:
                original_id = point_data['id']
                payload = point_data['payload']
                vector = point_data.get('vector',point_data['vector'])

                content = payload.get('content', '')
                title = payload.get('title', '')

                logger.info(f"Processing point {original_id}")
                logger.debug(f"Original title: {title}")
                logger.debug(f"Content preview: {content[:100]}...")

                # Enhanced parsing
                faculty_records = self.parse_faculty_entry_enhanced(content, payload)

                if faculty_records:
                    logger.info(f"Found {len(faculty_records)} valid faculty records")

                    # Show the enhanced faculty data
                    for record in faculty_records:
                        logger.info(f"  - {record.get('name', 'Unknown')} ({record.get('designation', 'Unknown')}) - {record.get('career_stage', 'Unknown Stage')}")

                    # Create enhanced content
                    structured_content = self.create_enhanced_content(faculty_records)

                    # Create intelligent title
                    new_title = self.create_intelligent_title(faculty_records, payload)

                    # Handle content chunking intelligently
                    if len(structured_content) > 1000:
                        documents = [Document(page_content=structured_content)]
                        chunks = self.text_splitter.split_documents(documents)

                        for i, chunk in enumerate(chunks):
                            new_point = PointStruct(
                                id=str(uuid.uuid4()),
                                payload={
                                    **payload,
                                    'content': chunk.page_content,
                                    'title': f"{new_title} - Part {i+1}" if len(chunks) > 1 else new_title,
                                    'chunk_index': i,
                                    'total_chunks': len(chunks),

                                    'content_type': 'faculty',
                                    'chunk_type': 'faculty',
                                    'category': 'Faculty',
                                    'faculty_count': len(faculty_records),
                                    'processing_timestamp': datetime.now().isoformat(),
                                    'enhanced_structure': True,
                                    'faculty_records': faculty_records,
                                    'quality_score': self._calculate_quality_score(faculty_records),
                                    'data_source': 'enhanced_processing'
                                },
                                vector=vector
                            )
                            updated_points.append(new_point)
                    else:
                        # Single chunk
                        new_point = PointStruct(
                            id=str(uuid.uuid4()),
                            payload={
                                **payload,
                                'content': structured_content,
                                'title': new_title,
                                'content_type': 'faculty',
                                'chunk_type': 'faculty',
                                'category': 'Faculty',
                                'faculty_count': len(faculty_records),
                                'processing_timestamp': datetime.now().isoformat(),
                                'enhanced_structure': True,
                                'faculty_records': faculty_records,
                                'quality_score': self._calculate_quality_score(faculty_records),
                                'data_source': 'enhanced_processing'
                            },
                            vector=vector
                        )
                        updated_points.append(new_point)

                    # Mark original for deletion
                    points_to_delete.append(original_id)
                    self.processing_stats['improved_points'] += 1

                    logger.info(f"✓ Enhanced point {original_id} -> {len(faculty_records)} records")

                else:
                    logger.warning(f"No valid faculty records found for point {original_id}")
                    # Keep original if no valid records found
                    continue

                self.processing_stats['successfully_parsed'] += 1

            except Exception as e:
                logger.error(f"Error processing point {point_data.get('id', 'unknown')}: {e}")
                self.processing_stats['processing_errors'].append(str(e))
                continue

        # Execute updates and deletions
        self._execute_collection_updates(updated_points, points_to_delete)

        # Generate and log final report
        self._generate_processing_report()

        logger.info("Enhanced faculty data cleaning process completed!")

    def _calculate_quality_score(self, faculty_records: List[Dict[str, Any]]) -> float:
        """Calculate quality score for faculty records"""
        if not faculty_records:
            return 0.0

        total_score = 0
        total_records = len(faculty_records)

        for record in faculty_records:
            record_score = 0
            max_score = 0

            # Essential fields (60 points)
            if record.get('name'):
                record_score += 20
            max_score += 20

            if record.get('designation'):
                record_score += 20
            max_score += 20

            if record.get('qualification'):
                record_score += 20
            max_score += 20

            # Additional fields (40 points)
            if record.get('experience'):
                record_score += 10
            max_score += 10

            if record.get('gender'):
                record_score += 10
            max_score += 10

            if record.get('joining_date'):
                record_score += 10
            max_score += 10

            if record.get('career_stage'):
                record_score += 10
            max_score += 10

            # Calculate percentage for this record
            if max_score > 0:
                total_score += (record_score / max_score) * 100

        return round(total_score / total_records, 2)

    def _execute_collection_updates(self, updated_points: List[PointStruct], points_to_delete: List[str]):
        """Execute batch updates and deletions"""
        if not updated_points and not points_to_delete:
            logger.info("No updates to perform")
            return

        try:
            # Batch upsert new points
            if updated_points:
                logger.info(f"Upserting {len(updated_points)} enhanced points...")
                self.client.upsert(
                    collection_name=self.collection_name,
                    points=updated_points
                )
                logger.info("✓ Successfully upserted enhanced points")

            # Batch delete old points
            if points_to_delete:
                logger.info(f"Deleting {len(points_to_delete)} original points...")
                self.client.delete(
                    collection_name=self.collection_name,
                    points_selector=points_to_delete
                )
                self.processing_stats['deleted_points'] = len(points_to_delete)
                logger.info("✓ Successfully deleted original points")

        except Exception as e:
            logger.error(f"Error executing collection updates: {e}")
            raise

    def _generate_processing_report(self):
        """Generate comprehensive processing report"""
        stats = self.processing_stats

        logger.info("\n" + "="*60)
        logger.info("ENHANCED FACULTY DATA PROCESSING REPORT")
        logger.info("="*60)

        # Overall statistics
        logger.info(f"Total Points Processed: {stats['total_processed']}")
        logger.info(f"Successfully Parsed: {stats['successfully_parsed']}")
        logger.info(f"Points Enhanced: {stats['improved_points']}")
        logger.info(f"Original Points Deleted: {stats['deleted_points']}")
        logger.info(f"Faculty Records Found: {stats['faculty_records_found']}")

        # Quality metrics
        success_rate = (stats['successfully_parsed'] / max(stats['total_processed'], 1)) * 100
        logger.info(f"Success Rate: {success_rate:.2f}%")

        # Designation distribution
        if stats['designation_distribution']:
            logger.info("\nDesignation Distribution:")
            for designation, count in Counter(stats['designation_distribution']).most_common():
                logger.info(f"  {designation}: {count}")

        # Qualification distribution
        if stats['qualification_distribution']:
            logger.info("\nQualification Distribution:")
            for qualification, count in Counter(stats['qualification_distribution']).most_common():
                logger.info(f"  {qualification}: {count}")

        # Error summary
        if stats['processing_errors']:
            logger.info(f"\nProcessing Errors ({len(stats['processing_errors'])}):")
            for error in stats['processing_errors'][:5]:  # Show first 5 errors
                logger.info(f"  - {error}")
            if len(stats['processing_errors']) > 5:
                logger.info(f"  ... and {len(stats['processing_errors']) - 5} more")

        logger.info("="*60)

    def verify_enhancements(self) -> Dict[str, Any]:
        """Verify the quality of enhancements made"""
        logger.info("Verifying enhancements...")

        # Fetch enhanced faculty data
        enhanced_points = self.fetch_faculty_data_optimized()

        verification_stats = {
            'total_enhanced_points': len(enhanced_points),
            'average_quality_score': 0.0,
            'faculty_records_total': 0,
            'complete_profiles': 0,
            'partial_profiles': 0,
            'career_stage_distribution': defaultdict(int),
            'location_coverage': defaultdict(int),
            'verification_errors': []
        }

        total_quality_score = 0

        for point_data in enhanced_points:
            try:
                payload = point_data['payload']

                # Check for enhanced structure
                if not payload.get('enhanced_structure'):
                    continue

                # Get quality score
                quality_score = payload.get('quality_score', 0.0)
                total_quality_score += quality_score

                # Count faculty records
                faculty_records = payload.get('faculty_records', [])
                verification_stats['faculty_records_total'] += len(faculty_records)

                # Analyze completeness
                for record in faculty_records:
                    essential_fields = ['name', 'designation', 'qualification']
                    complete_fields = sum(1 for field in essential_fields if record.get(field))

                    if complete_fields == len(essential_fields):
                        verification_stats['complete_profiles'] += 1
                    else:
                        verification_stats['partial_profiles'] += 1

                    # Career stage distribution
                    career_stage = record.get('career_stage', 'Unknown')
                    verification_stats['career_stage_distribution'][career_stage] += 1

                    # Location coverage
                    location = record.get('city', 'Unknown Location')
                    verification_stats['location_coverage'][location] += 1

            except Exception as e:
                verification_stats['verification_errors'].append(str(e))

        # Calculate average quality score
        if enhanced_points:
            verification_stats['average_quality_score'] = round(
                total_quality_score / len(enhanced_points), 2
            )

        # Log verification results
        logger.info("\n" + "="*50)
        logger.info("ENHANCEMENT VERIFICATION REPORT")
        logger.info("="*50)
        logger.info(f"Total Enhanced Points: {verification_stats['total_enhanced_points']}")
        logger.info(f"Average Quality Score: {verification_stats['average_quality_score']}")
        logger.info(f"Total Faculty Records: {verification_stats['faculty_records_total']}")
        logger.info(f"Complete Profiles: {verification_stats['complete_profiles']}")
        logger.info(f"Partial Profiles: {verification_stats['partial_profiles']}")

        if verification_stats['career_stage_distribution']:
            logger.info("\nCareer Stage Distribution:")
            for stage, count in Counter(verification_stats['career_stage_distribution']).most_common():
                logger.info(f"  {stage}: {count}")

        if verification_stats['location_coverage']:
            logger.info("\nLocation Coverage:")
            for location, count in Counter(verification_stats['location_coverage']).most_common():
                logger.info(f"  {location}: {count}")

        logger.info("="*50)

        return verification_stats

    def export_enhanced_data(self, output_file: str = "enhanced_faculty_data.json"):
        """Export enhanced faculty data to JSON file"""
        logger.info(f"Exporting enhanced faculty data to {output_file}...")

        # Fetch all enhanced faculty data
        enhanced_points = self.fetch_faculty_data_optimized()

        export_data = {
            'metadata': {
                'export_timestamp': datetime.now().isoformat(),
                'total_points': len(enhanced_points),
                'export_version': '1.0'
            },
            'faculty_data': []
        }

        for point_data in enhanced_points:
            payload = point_data['payload']

            if payload.get('enhanced_structure'):
                export_entry = {
                    'id': point_data['id'],
                    'title': payload.get('title', ''),
                    'content': payload.get('content', ''),
                    'faculty_records': payload.get('faculty_records', []),
                    'quality_score': payload.get('quality_score', 0.0),
                    'processing_timestamp': payload.get('processing_timestamp', ''),
                    'location': {
                        'city': payload.get('city', ''),
                        'state': payload.get('state', ''),
                        'region': payload.get('region', '')
                    }
                }
                export_data['faculty_data'].append(export_entry)

        # Save to file
        with open(output_file, 'w', encoding='utf-8') as f:
            json.dump(export_data, f, indent=2, ensure_ascii=False)

        logger.info(f"✓ Successfully exported {len(export_data['faculty_data'])} enhanced faculty records")
        return output_file


# Usage example and main execution
if __name__ == "__main__":
    # Configuration
    QDRANT_URL = "https://b5651607-31ce-49ba-916d-c35c89d731d2.us-east4-0.gcp.cloud.qdrant.io"
    API_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY2Nlc3MiOiJtIn0.0ApHZL4Qn_A8bx7FCC62nx-IOrHI84W7GZlUZEyVgKk"
    COLLECTION_NAME = '282005'

    # Initialize enhanced cleaner
    cleaner = EnhancedFacultyDataCleaner(
        qdrant_url=QDRANT_URL,
        api_key=API_KEY,
        collection_name=COLLECTION_NAME
    )

    try:
        # Execute enhanced processing
        cleaner.process_and_update_collection_enhanced()

        # Verify enhancements
        verification_results = cleaner.verify_enhancements()

        # Export enhanced data
        export_file = cleaner.export_enhanced_data("enhanced_faculty_data.json")

        logger.info("All processing completed successfully!")
        logger.info(f"Enhanced data exported to: {export_file}")

    except Exception as e:
        logger.error(f"Processing failed: {e}")
        raise
# Out:
# Streaming output truncated to the last 5000 lines.
# 2025-07-21 06:32:04,632 - __main__ - INFO -   - Nadeem Akhtar (Assistant Professor) - Mid Career
# INFO:__main__:  - Nadeem Akhtar (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,633 - __main__ - INFO -   - Syed Fahad Anwar (Professor) - Senior Career
# INFO:__main__:  - Syed Fahad Anwar (Professor) - Senior Career
# 2025-07-21 06:32:04,634 - __main__ - INFO - ✓ Enhanced point 11ca2279-ed34-4acf-800c-023e3834ce53 -> 2 records
# INFO:__main__:✓ Enhanced point 11ca2279-ed34-4acf-800c-023e3834ce53 -> 2 records
# 2025-07-21 06:32:04,635 - __main__ - INFO - Processing point 1266ba28-66da-450f-b22b-5d2bfa558ec2
# INFO:__main__:Processing point 1266ba28-66da-450f-b22b-5d2bfa558ec2
# 2025-07-21 06:32:04,636 - __main__ - INFO - Using pattern 'pipe_separated' - found 2 matches
# INFO:__main__:Using pattern 'pipe_separated' - found 2 matches
# 2025-07-21 06:32:04,637 - __main__ - INFO - Found 2 valid faculty records
# INFO:__main__:Found 2 valid faculty records
# 2025-07-21 06:32:04,639 - __main__ - INFO -   - Rahul Harishchandra Meshr Am (Assistant Professor) - Early Career
# INFO:__main__:  - Rahul Harishchandra Meshr Am (Assistant Professor) - Early Career
# 2025-07-21 06:32:04,640 - __main__ - INFO -   - Surendra Babu Anantharaman (Assistant Professor) - Early Career
# INFO:__main__:  - Surendra Babu Anantharaman (Assistant Professor) - Early Career
# 2025-07-21 06:32:04,641 - __main__ - INFO - ✓ Enhanced point 1266ba28-66da-450f-b22b-5d2bfa558ec2 -> 2 records
# INFO:__main__:✓ Enhanced point 1266ba28-66da-450f-b22b-5d2bfa558ec2 -> 2 records
# 2025-07-21 06:32:04,642 - __main__ - INFO - Processing point 12d69900-364b-409e-ae10-d799a6b81926
# INFO:__main__:Processing point 12d69900-364b-409e-ae10-d799a6b81926
# 2025-07-21 06:32:04,643 - __main__ - INFO - Using pattern 'pipe_separated' - found 1 matches
# INFO:__main__:Using pattern 'pipe_separated' - found 1 matches
# 2025-07-21 06:32:04,644 - __main__ - INFO - Found 1 valid faculty records
# INFO:__main__:Found 1 valid faculty records
# 2025-07-21 06:32:04,645 - __main__ - INFO -   - Nesar Ahmad (Professor) - Distinguished Career
# INFO:__main__:  - Nesar Ahmad (Professor) - Distinguished Career
# 2025-07-21 06:32:04,646 - __main__ - INFO - ✓ Enhanced point 12d69900-364b-409e-ae10-d799a6b81926 -> 1 records
# INFO:__main__:✓ Enhanced point 12d69900-364b-409e-ae10-d799a6b81926 -> 1 records
# 2025-07-21 06:32:04,648 - __main__ - INFO - Processing point 1318a0fe-6b5a-4ec8-96d9-4898ed143024
# INFO:__main__:Processing point 1318a0fe-6b5a-4ec8-96d9-4898ed143024
# 2025-07-21 06:32:04,649 - __main__ - INFO - Using pattern 'basic_entry' - found 6 matches
# INFO:__main__:Using pattern 'basic_entry' - found 6 matches
# 2025-07-21 06:32:04,650 - __main__ - INFO - Found 6 valid faculty records
# INFO:__main__:Found 6 valid faculty records
# 2025-07-21 06:32:04,651 - __main__ - INFO -   - Rupen Goswami (Professor) - Senior Career
# INFO:__main__:  - Rupen Goswami (Professor) - Senior Career
# 2025-07-21 06:32:04,652 - __main__ - INFO -   - P V Manivannan (Associate Professor) - Mid Career
# INFO:__main__:  - P V Manivannan (Associate Professor) - Mid Career
# 2025-07-21 06:32:04,653 - __main__ - INFO -   - M Senthil Murugan (Assistant Professor) - Mid Career
# INFO:__main__:  - M Senthil Murugan (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,654 - __main__ - INFO -   - Arun K Tangirala (Professor) - Distinguished Career
# INFO:__main__:  - Arun K Tangirala (Professor) - Distinguished Career
# 2025-07-21 06:32:04,655 - __main__ - INFO -   - R K Amit (Professor) - Senior Career
# INFO:__main__:  - R K Amit (Professor) - Senior Career
# 2025-07-21 06:32:04,656 - __main__ - INFO -   - Puduru Viswanadha (Assistant Professor) - Mid Career
# INFO:__main__:  - Puduru Viswanadha (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,658 - __main__ - INFO - ✓ Enhanced point 1318a0fe-6b5a-4ec8-96d9-4898ed143024 -> 6 records
# INFO:__main__:✓ Enhanced point 1318a0fe-6b5a-4ec8-96d9-4898ed143024 -> 6 records
# 2025-07-21 06:32:04,659 - __main__ - INFO - Processing point 13457079-6328-4b1a-9840-a45baa17fe76
# INFO:__main__:Processing point 13457079-6328-4b1a-9840-a45baa17fe76
# 2025-07-21 06:32:04,660 - __main__ - INFO - Using pattern 'pipe_separated' - found 5 matches
# INFO:__main__:Using pattern 'pipe_separated' - found 5 matches
# 2025-07-21 06:32:04,662 - __main__ - INFO - Found 5 valid faculty records
# INFO:__main__:Found 5 valid faculty records
# 2025-07-21 06:32:04,663 - __main__ - INFO -   - S Krishna (Associate Professor) - Senior Career
# INFO:__main__:  - S Krishna (Associate Professor) - Senior Career
# 2025-07-21 06:32:04,664 - __main__ - INFO -   - Amitava Ghosh (Professor) - Senior Career
# INFO:__main__:  - Amitava Ghosh (Professor) - Senior Career
# 2025-07-21 06:32:04,665 - __main__ - INFO -   - Prahallad Padhan (Professor) - Senior Career
# INFO:__main__:  - Prahallad Padhan (Professor) - Senior Career
# 2025-07-21 06:32:04,666 - __main__ - INFO -   - Krithika Narayanaswamy (Assistant Professor) - Mid Career
# INFO:__main__:  - Krithika Narayanaswamy (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,667 - __main__ - INFO -   - Manoj Pandey (Assistant Professor) - Mid Career
# INFO:__main__:  - Manoj Pandey (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,668 - __main__ - INFO - ✓ Enhanced point 13457079-6328-4b1a-9840-a45baa17fe76 -> 5 records
# INFO:__main__:✓ Enhanced point 13457079-6328-4b1a-9840-a45baa17fe76 -> 5 records
# 2025-07-21 06:32:04,669 - __main__ - INFO - Processing point 14380014-2842-4687-8d6d-0cbbe0df53ab
# INFO:__main__:Processing point 14380014-2842-4687-8d6d-0cbbe0df53ab
# 2025-07-21 06:32:04,670 - __main__ - INFO - Using pattern 'pipe_separated' - found 5 matches
# INFO:__main__:Using pattern 'pipe_separated' - found 5 matches
# 2025-07-21 06:32:04,672 - __main__ - INFO - Found 5 valid faculty records
# INFO:__main__:Found 5 valid faculty records
# 2025-07-21 06:32:04,673 - __main__ - INFO -   - Deepak Kumar (Professor) - Senior Career
# INFO:__main__:  - Deepak Kumar (Professor) - Senior Career
# 2025-07-21 06:32:04,674 - __main__ - INFO -   - Rajesh Narayanan (Professor) - Senior Career
# INFO:__main__:  - Rajesh Narayanan (Professor) - Senior Career
# 2025-07-21 06:32:04,675 - __main__ - INFO -   - A R Ganesan (Professor) - Senior Career
# INFO:__main__:  - A R Ganesan (Professor) - Senior Career
# 2025-07-21 06:32:04,676 - __main__ - INFO -   - Mohanashankar Sivaprakasam (Professor) - Senior Career
# INFO:__main__:  - Mohanashankar Sivaprakasam (Professor) - Senior Career
# 2025-07-21 06:32:04,677 - __main__ - INFO -   - Venkatakrishnan P (Professor) - Senior Career
# INFO:__main__:  - Venkatakrishnan P (Professor) - Senior Career
# 2025-07-21 06:32:04,678 - __main__ - INFO - ✓ Enhanced point 14380014-2842-4687-8d6d-0cbbe0df53ab -> 5 records
# INFO:__main__:✓ Enhanced point 14380014-2842-4687-8d6d-0cbbe0df53ab -> 5 records
# 2025-07-21 06:32:04,679 - __main__ - INFO - Processing point 14e47a2a-c672-40cb-94de-2e2f45b8966b
# INFO:__main__:Processing point 14e47a2a-c672-40cb-94de-2e2f45b8966b
# 2025-07-21 06:32:04,680 - __main__ - INFO - Using pattern 'basic_entry' - found 5 matches
# INFO:__main__:Using pattern 'basic_entry' - found 5 matches
# 2025-07-21 06:32:04,681 - __main__ - INFO - Found 5 valid faculty records
# INFO:__main__:Found 5 valid faculty records
# 2025-07-21 06:32:04,684 - __main__ - INFO -   - Mohd Yasir (Assistant Professor) - Early Career
# INFO:__main__:  - Mohd Yasir (Assistant Professor) - Early Career
# 2025-07-21 06:32:04,685 - __main__ - INFO -   - Syed Mohammad (Assistant Professor) - Early Career
# INFO:__main__:  - Syed Mohammad (Assistant Professor) - Early Career
# 2025-07-21 06:32:04,687 - __main__ - INFO -   - Abdus Samad (Associate Professor) - Mid Career
# INFO:__main__:  - Abdus Samad (Associate Professor) - Mid Career
# 2025-07-21 06:32:04,687 - __main__ - INFO -   - Wasi Ur Rahman (Assistant Professor) - Early Career
# INFO:__main__:  - Wasi Ur Rahman (Assistant Professor) - Early Career
# 2025-07-21 06:32:04,688 - __main__ - INFO -   - M Tabish (Assistant Professor) - Early Career
# INFO:__main__:  - M Tabish (Assistant Professor) - Early Career
# 2025-07-21 06:32:04,690 - __main__ - INFO - ✓ Enhanced point 14e47a2a-c672-40cb-94de-2e2f45b8966b -> 5 records
# INFO:__main__:✓ Enhanced point 14e47a2a-c672-40cb-94de-2e2f45b8966b -> 5 records
# 2025-07-21 06:32:04,691 - __main__ - INFO - Processing point 154d38a5-dcf1-4fd3-955c-4c7bed99a959
# INFO:__main__:Processing point 154d38a5-dcf1-4fd3-955c-4c7bed99a959
# 2025-07-21 06:32:04,692 - __main__ - INFO - Using pattern 'basic_entry' - found 6 matches
# INFO:__main__:Using pattern 'basic_entry' - found 6 matches
# 2025-07-21 06:32:04,693 - __main__ - INFO - Found 6 valid faculty records
# INFO:__main__:Found 6 valid faculty records
# 2025-07-21 06:32:04,694 - __main__ - INFO -   - Amitava Ghosh (Professor) - Senior Career
# INFO:__main__:  - Amitava Ghosh (Professor) - Senior Career
# 2025-07-21 06:32:04,695 - __main__ - INFO -   - Prahallad Padhan (Professor) - Senior Career
# INFO:__main__:  - Prahallad Padhan (Professor) - Senior Career
# 2025-07-21 06:32:04,696 - __main__ - INFO -   - Krithika (Assistant Professor) - Mid Career
# INFO:__main__:  - Krithika (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,697 - __main__ - INFO -   - Manoj Pandey (Assistant Professor) - Mid Career
# INFO:__main__:  - Manoj Pandey (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,699 - __main__ - INFO -   - Vani Janakiraman (Associate Professor) - Mid Career
# INFO:__main__:  - Vani Janakiraman (Associate Professor) - Mid Career
# 2025-07-21 06:32:04,700 - __main__ - INFO -   - Ethayaraja Mani (Professor) - Senior Career
# INFO:__main__:  - Ethayaraja Mani (Professor) - Senior Career
# 2025-07-21 06:32:04,701 - __main__ - INFO - ✓ Enhanced point 154d38a5-dcf1-4fd3-955c-4c7bed99a959 -> 6 records
# INFO:__main__:✓ Enhanced point 154d38a5-dcf1-4fd3-955c-4c7bed99a959 -> 6 records
# 2025-07-21 06:32:04,702 - __main__ - INFO - Processing point 15d375be-f439-4554-8292-fc1a7dd9b83c
# INFO:__main__:Processing point 15d375be-f439-4554-8292-fc1a7dd9b83c
# 2025-07-21 06:32:04,703 - __main__ - INFO - Using pattern 'pipe_separated' - found 4 matches
# INFO:__main__:Using pattern 'pipe_separated' - found 4 matches
# 2025-07-21 06:32:04,705 - __main__ - INFO - Found 4 valid faculty records
# INFO:__main__:Found 4 valid faculty records
# 2025-07-21 06:32:04,706 - __main__ - INFO -   - Salman Hameed (Professor) - Distinguished Career
# INFO:__main__:  - Salman Hameed (Professor) - Distinguished Career
# 2025-07-21 06:32:04,707 - __main__ - INFO -   - Shamshad Husain (Professor) - Distinguished Career
# INFO:__main__:  - Shamshad Husain (Professor) - Distinguished Career
# 2025-07-21 06:32:04,708 - __main__ - INFO -   - Akhtar Husain Ansari (Professor) - Senior Career
# INFO:__main__:  - Akhtar Husain Ansari (Professor) - Senior Career
# 2025-07-21 06:32:04,709 - __main__ - INFO -   - Azhar Jamil (Assistant Professor) - Mid Career
# INFO:__main__:  - Azhar Jamil (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,711 - __main__ - INFO - ✓ Enhanced point 15d375be-f439-4554-8292-fc1a7dd9b83c -> 4 records
# INFO:__main__:✓ Enhanced point 15d375be-f439-4554-8292-fc1a7dd9b83c -> 4 records
# 2025-07-21 06:32:04,712 - __main__ - INFO - Processing point 15f40238-c30d-4f31-a735-45fb75390e99
# INFO:__main__:Processing point 15f40238-c30d-4f31-a735-45fb75390e99
# 2025-07-21 06:32:04,713 - __main__ - INFO - Using pattern 'basic_entry' - found 6 matches
# INFO:__main__:Using pattern 'basic_entry' - found 6 matches
# 2025-07-21 06:32:04,714 - __main__ - INFO - Found 6 valid faculty records
# INFO:__main__:Found 6 valid faculty records
# 2025-07-21 06:32:04,715 - __main__ - INFO -   - Izharuddin (Professor) - Distinguished Career
# INFO:__main__:  - Izharuddin (Professor) - Distinguished Career
# 2025-07-21 06:32:04,716 - __main__ - INFO -   - Parveen (Professor) - Distinguished Career
# INFO:__main__:  - Parveen (Professor) - Distinguished Career
# 2025-07-21 06:32:04,717 - __main__ - INFO -   - Sohail Ayub (Professor) - Distinguished Career
# INFO:__main__:  - Sohail Ayub (Professor) - Distinguished Career
# 2025-07-21 06:32:04,718 - __main__ - INFO -   - S Maheshwari (Professor) - Distinguished Career
# INFO:__main__:  - S Maheshwari (Professor) - Distinguished Career
# 2025-07-21 06:32:04,719 - __main__ - INFO -   - Yasser Azim (Assistant Professor) - Mid Career
# INFO:__main__:  - Yasser Azim (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,721 - __main__ - INFO -   - Saeikh Z Hasan (Assistant Professor) - Mid Career
# INFO:__main__:  - Saeikh Z Hasan (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,722 - __main__ - INFO - ✓ Enhanced point 15f40238-c30d-4f31-a735-45fb75390e99 -> 6 records
# INFO:__main__:✓ Enhanced point 15f40238-c30d-4f31-a735-45fb75390e99 -> 6 records
# 2025-07-21 06:32:04,723 - __main__ - INFO - Processing point 16d85f72-c137-45f5-b3b9-00d31024e0cd
# INFO:__main__:Processing point 16d85f72-c137-45f5-b3b9-00d31024e0cd
# 2025-07-21 06:32:04,724 - __main__ - INFO - Using pattern 'basic_entry' - found 5 matches
# INFO:__main__:Using pattern 'basic_entry' - found 5 matches
# 2025-07-21 06:32:04,725 - __main__ - INFO - Found 5 valid faculty records
# INFO:__main__:Found 5 valid faculty records
# 2025-07-21 06:32:04,726 - __main__ - INFO -   - M A Farooqi (Associate Professor) - Mid Career
# INFO:__main__:  - M A Farooqi (Associate Professor) - Mid Career
# 2025-07-21 06:32:04,727 - __main__ - INFO -   - Mohd Sarfaraz (Assistant Professor) - Mid Career
# INFO:__main__:  - Mohd Sarfaraz (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,728 - __main__ - INFO -   - Nabiullah Khan (Associate Professor) - Senior Career
# INFO:__main__:  - Nabiullah Khan (Associate Professor) - Senior Career
# 2025-07-21 06:32:04,729 - __main__ - INFO -   - Mubashshir A (Professor) - Distinguished Career
# INFO:__main__:  - Mubashshir A (Professor) - Distinguished Career
# 2025-07-21 06:32:04,733 - __main__ - INFO -   - Asfar A Khan (Professor) - Distinguished Career
# INFO:__main__:  - Asfar A Khan (Professor) - Distinguished Career
# 2025-07-21 06:32:04,734 - __main__ - INFO - ✓ Enhanced point 16d85f72-c137-45f5-b3b9-00d31024e0cd -> 5 records
# INFO:__main__:✓ Enhanced point 16d85f72-c137-45f5-b3b9-00d31024e0cd -> 5 records
# 2025-07-21 06:32:04,735 - __main__ - INFO - Processing point 1774d56e-78c2-4af2-b24c-1bc6ad52bbbd
# INFO:__main__:Processing point 1774d56e-78c2-4af2-b24c-1bc6ad52bbbd
# 2025-07-21 06:32:04,736 - __main__ - INFO - Using pattern 'basic_entry' - found 5 matches
# INFO:__main__:Using pattern 'basic_entry' - found 5 matches
# 2025-07-21 06:32:04,737 - __main__ - INFO - Found 5 valid faculty records
# INFO:__main__:Found 5 valid faculty records
# 2025-07-21 06:32:04,738 - __main__ - INFO -   - Swathi Sudhakar (Assistant Professor) - Early Career
# INFO:__main__:  - Swathi Sudhakar (Assistant Professor) - Early Career
# 2025-07-21 06:32:04,740 - __main__ - INFO -   - Ravichandran (Assistant Professor) - Early Career
# INFO:__main__:  - Ravichandran (Assistant Professor) - Early Career
# 2025-07-21 06:32:04,741 - __main__ - INFO -   - Sreeparvathy Vijay (Assistant Professor) - Early Career
# INFO:__main__:  - Sreeparvathy Vijay (Assistant Professor) - Early Career
# 2025-07-21 06:32:04,742 - __main__ - INFO -   - Rahul (Assistant Professor) - Early Career
# INFO:__main__:  - Rahul (Assistant Professor) - Early Career
# 2025-07-21 06:32:04,743 - __main__ - INFO -   - Surendra Babu (Assistant Professor) - Early Career
# INFO:__main__:  - Surendra Babu (Assistant Professor) - Early Career
# 2025-07-21 06:32:04,744 - __main__ - INFO - ✓ Enhanced point 1774d56e-78c2-4af2-b24c-1bc6ad52bbbd -> 5 records
# INFO:__main__:✓ Enhanced point 1774d56e-78c2-4af2-b24c-1bc6ad52bbbd -> 5 records
# 2025-07-21 06:32:04,745 - __main__ - INFO - Processing point 184197d9-43e9-4d0c-8c65-f3b116919800
# INFO:__main__:Processing point 184197d9-43e9-4d0c-8c65-f3b116919800
# 2025-07-21 06:32:04,746 - __main__ - INFO - Using pattern 'basic_entry' - found 2 matches
# INFO:__main__:Using pattern 'basic_entry' - found 2 matches
# 2025-07-21 06:32:04,747 - __main__ - INFO - Found 2 valid faculty records
# INFO:__main__:Found 2 valid faculty records
# 2025-07-21 06:32:04,748 - __main__ - INFO -   - Mohd Faisal Jalil (Assistant Professor) - Early Career
# INFO:__main__:  - Mohd Faisal Jalil (Assistant Professor) - Early Career
# 2025-07-21 06:32:04,749 - __main__ - INFO -   - Mohammad Ashraf (Assistant Professor) - Early Career
# INFO:__main__:  - Mohammad Ashraf (Assistant Professor) - Early Career
# 2025-07-21 06:32:04,751 - __main__ - INFO - ✓ Enhanced point 184197d9-43e9-4d0c-8c65-f3b116919800 -> 2 records
# INFO:__main__:✓ Enhanced point 184197d9-43e9-4d0c-8c65-f3b116919800 -> 2 records
# 2025-07-21 06:32:04,752 - __main__ - INFO - Processing point 1846b234-1ad7-4edb-97fe-4c11aff82fec
# INFO:__main__:Processing point 1846b234-1ad7-4edb-97fe-4c11aff82fec
# 2025-07-21 06:32:04,753 - __main__ - INFO - Using pattern 'basic_entry' - found 7 matches
# INFO:__main__:Using pattern 'basic_entry' - found 7 matches
# 2025-07-21 06:32:04,754 - __main__ - INFO - Found 7 valid faculty records
# INFO:__main__:Found 7 valid faculty records
# 2025-07-21 06:32:04,755 - __main__ - INFO -   - M N Jayalal (Professor) - Senior Career
# INFO:__main__:  - M N Jayalal (Professor) - Senior Career
# 2025-07-21 06:32:04,756 - __main__ - INFO -   - Tanmay Basak (Professor) - Distinguished Career
# INFO:__main__:  - Tanmay Basak (Professor) - Distinguished Career
# 2025-07-21 06:32:04,757 - __main__ - INFO -   - G Ranga Rao (Professor) - Distinguished Career
# INFO:__main__:  - G Ranga Rao (Professor) - Distinguished Career
# 2025-07-21 06:32:04,758 - __main__ - INFO -   - Sankaran (Professor) - Senior Career
# INFO:__main__:  - Sankaran (Professor) - Senior Career
# 2025-07-21 06:32:04,759 - __main__ - INFO -   - Abhijit P (Professor) - Distinguished Career
# INFO:__main__:  - Abhijit P (Professor) - Distinguished Career
# 2025-07-21 06:32:04,760 - __main__ - INFO -   - R Radha (Professor) - Distinguished Career
# INFO:__main__:  - R Radha (Professor) - Distinguished Career
# 2025-07-21 06:32:04,761 - __main__ - INFO -   - Lakshmi Priya P S (Assistant Professor) - Mid Career
# INFO:__main__:  - Lakshmi Priya P S (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,763 - __main__ - INFO - ✓ Enhanced point 1846b234-1ad7-4edb-97fe-4c11aff82fec -> 7 records
# INFO:__main__:✓ Enhanced point 1846b234-1ad7-4edb-97fe-4c11aff82fec -> 7 records
# 2025-07-21 06:32:04,764 - __main__ - INFO - Processing point 1882d213-8ae3-4893-b8c1-4d5920f5ae16
# INFO:__main__:Processing point 1882d213-8ae3-4893-b8c1-4d5920f5ae16
# 2025-07-21 06:32:04,765 - __main__ - INFO - Using pattern 'basic_entry' - found 3 matches
# INFO:__main__:Using pattern 'basic_entry' - found 3 matches
# 2025-07-21 06:32:04,766 - __main__ - INFO - Found 3 valid faculty records
# INFO:__main__:Found 3 valid faculty records
# 2025-07-21 06:32:04,767 - __main__ - INFO -   - Rachel Kalpana (Associate Professor) - Mid Career
# INFO:__main__:  - Rachel Kalpana (Associate Professor) - Mid Career
# 2025-07-21 06:32:04,769 - __main__ - INFO -   - R Ravi Krishna (Professor) - Senior Career
# INFO:__main__:  - R Ravi Krishna (Professor) - Senior Career
# 2025-07-21 06:32:04,770 - __main__ - INFO -   - K Sumesh (Assistant Professor) - Mid Career
# INFO:__main__:  - K Sumesh (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,771 - __main__ - INFO - ✓ Enhanced point 1882d213-8ae3-4893-b8c1-4d5920f5ae16 -> 3 records
# INFO:__main__:✓ Enhanced point 1882d213-8ae3-4893-b8c1-4d5920f5ae16 -> 3 records
# 2025-07-21 06:32:04,772 - __main__ - INFO - Processing point 18b261e1-7ee9-4246-9adc-a00883d16173
# INFO:__main__:Processing point 18b261e1-7ee9-4246-9adc-a00883d16173
# 2025-07-21 06:32:04,773 - __main__ - INFO - Using pattern 'basic_entry' - found 2 matches
# INFO:__main__:Using pattern 'basic_entry' - found 2 matches
# 2025-07-21 06:32:04,774 - __main__ - INFO - Found 2 valid faculty records
# INFO:__main__:Found 2 valid faculty records
# 2025-07-21 06:32:04,775 - __main__ - INFO -   - Priyanka Shukla (Assistant Professor) - Mid Career
# INFO:__main__:  - Priyanka Shukla (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,776 - __main__ - INFO -   - Masilamani (Professor) - Senior Career
# INFO:__main__:  - Masilamani (Professor) - Senior Career
# 2025-07-21 06:32:04,778 - __main__ - INFO - ✓ Enhanced point 18b261e1-7ee9-4246-9adc-a00883d16173 -> 2 records
# INFO:__main__:✓ Enhanced point 18b261e1-7ee9-4246-9adc-a00883d16173 -> 2 records
# 2025-07-21 06:32:04,779 - __main__ - INFO - Processing point 19b611f5-89ec-43da-96e6-a2a57e610d79
# INFO:__main__:Processing point 19b611f5-89ec-43da-96e6-a2a57e610d79
# 2025-07-21 06:32:04,780 - __main__ - INFO - Using pattern 'basic_entry' - found 5 matches
# INFO:__main__:Using pattern 'basic_entry' - found 5 matches
# 2025-07-21 06:32:04,781 - __main__ - INFO - Found 5 valid faculty records
# INFO:__main__:Found 5 valid faculty records
# 2025-07-21 06:32:04,782 - __main__ - INFO -   - Jithin John (Associate Professor) - Mid Career
# INFO:__main__:  - Jithin John (Associate Professor) - Mid Career
# 2025-07-21 06:32:04,783 - __main__ - INFO -   - Bhaswar (Assistant Professor) - Mid Career
# INFO:__main__:  - Bhaswar (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,784 - __main__ - INFO -   - Chandan Sarangi (Assistant Professor) - Mid Career
# INFO:__main__:  - Chandan Sarangi (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,785 - __main__ - INFO -   - Ninitha Margret (Assistant Professor) - Mid Career
# INFO:__main__:  - Ninitha Margret (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,787 - __main__ - INFO -   - Akanksha Agrawal (Assistant Professor) - Mid Career
# INFO:__main__:  - Akanksha Agrawal (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,789 - __main__ - INFO - ✓ Enhanced point 19b611f5-89ec-43da-96e6-a2a57e610d79 -> 5 records
# INFO:__main__:✓ Enhanced point 19b611f5-89ec-43da-96e6-a2a57e610d79 -> 5 records
# 2025-07-21 06:32:04,790 - __main__ - INFO - Processing point 1a8043fe-5e94-4ff4-b733-822f19ec55fb
# INFO:__main__:Processing point 1a8043fe-5e94-4ff4-b733-822f19ec55fb
# 2025-07-21 06:32:04,791 - __main__ - INFO - Using pattern 'basic_entry' - found 6 matches
# INFO:__main__:Using pattern 'basic_entry' - found 6 matches
# 2025-07-21 06:32:04,793 - __main__ - INFO - Found 6 valid faculty records
# INFO:__main__:Found 6 valid faculty records
# 2025-07-21 06:32:04,794 - __main__ - INFO -   - Manoj (Professor) - Senior Career
# INFO:__main__:  - Manoj (Professor) - Senior Career
# 2025-07-21 06:32:04,795 - __main__ - INFO -   - Aravind Kumar (Associate Professor) - Mid Career
# INFO:__main__:  - Aravind Kumar (Associate Professor) - Mid Career
# 2025-07-21 06:32:04,799 - __main__ - INFO -   - A Seshadri (Professor) - Senior Career
# INFO:__main__:  - A Seshadri (Professor) - Senior Career
# 2025-07-21 06:32:04,800 - __main__ - INFO -   - P Ramkumar (Professor) - Senior Career
# INFO:__main__:  - P Ramkumar (Professor) - Senior Career
# 2025-07-21 06:32:04,801 - __main__ - INFO -   - Vignesh (Professor) - Senior Career
# INFO:__main__:  - Vignesh (Professor) - Senior Career
# 2025-07-21 06:32:04,802 - __main__ - INFO -   - K C Sivakumar (Professor) - Distinguished Career
# INFO:__main__:  - K C Sivakumar (Professor) - Distinguished Career
# 2025-07-21 06:32:04,805 - __main__ - INFO - ✓ Enhanced point 1a8043fe-5e94-4ff4-b733-822f19ec55fb -> 6 records
# INFO:__main__:✓ Enhanced point 1a8043fe-5e94-4ff4-b733-822f19ec55fb -> 6 records
# 2025-07-21 06:32:04,806 - __main__ - INFO - Processing point 1aa0d98f-fbac-4579-9271-f6900d51c49e
# INFO:__main__:Processing point 1aa0d98f-fbac-4579-9271-f6900d51c49e
# 2025-07-21 06:32:04,807 - __main__ - INFO - Using pattern 'pipe_separated' - found 5 matches
# INFO:__main__:Using pattern 'pipe_separated' - found 5 matches
# 2025-07-21 06:32:04,808 - __main__ - INFO - Found 5 valid faculty records
# INFO:__main__:Found 5 valid faculty records
# 2025-07-21 06:32:04,809 - __main__ - INFO -   - Khusro Qasim (Assistant Professor) - Mid Career
# INFO:__main__:  - Khusro Qasim (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,810 - __main__ - INFO -   - Javed Alam (Professor) - Distinguished Career
# INFO:__main__:  - Javed Alam (Professor) - Distinguished Career
# 2025-07-21 06:32:04,811 - __main__ - INFO -   - Aijaz Masood (Professor) - Distinguished Career
# INFO:__main__:  - Aijaz Masood (Professor) - Distinguished Career
# 2025-07-21 06:32:04,812 - __main__ - INFO -   - Mohd Wajid (Associate Professor) - Mid Career
# INFO:__main__:  - Mohd Wajid (Associate Professor) - Mid Career
# 2025-07-21 06:32:04,813 - __main__ - INFO -   - Ameer Azam (Professor) - Distinguished Career
# INFO:__main__:  - Ameer Azam (Professor) - Distinguished Career
# 2025-07-21 06:32:04,815 - __main__ - INFO - ✓ Enhanced point 1aa0d98f-fbac-4579-9271-f6900d51c49e -> 5 records
# INFO:__main__:✓ Enhanced point 1aa0d98f-fbac-4579-9271-f6900d51c49e -> 5 records
# 2025-07-21 06:32:04,816 - __main__ - INFO - Processing point 1d9980b0-eb6c-41dd-92f9-36c57d3c5f07
# INFO:__main__:Processing point 1d9980b0-eb6c-41dd-92f9-36c57d3c5f07
# 2025-07-21 06:32:04,817 - __main__ - INFO - Using pattern 'basic_entry' - found 6 matches
# INFO:__main__:Using pattern 'basic_entry' - found 6 matches
# 2025-07-21 06:32:04,818 - __main__ - INFO - Found 6 valid faculty records
# INFO:__main__:Found 6 valid faculty records
# 2025-07-21 06:32:04,819 - __main__ - INFO -   - Muhammed Muaz (Assistant Professor) - Early Career
# INFO:__main__:  - Muhammed Muaz (Assistant Professor) - Early Career
# 2025-07-21 06:32:04,820 - __main__ - INFO -   - Syed Muhammad (Assistant Professor) - Mid Career
# INFO:__main__:  - Syed Muhammad (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,821 - __main__ - INFO -   - Mohammad Suhaib (Assistant Professor) - Early Career
# INFO:__main__:  - Mohammad Suhaib (Assistant Professor) - Early Career
# 2025-07-21 06:32:04,822 - __main__ - INFO -   - Mohammad Hashim (Assistant Professor) - Mid Career
# INFO:__main__:  - Mohammad Hashim (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,823 - __main__ - INFO -   - Hilal Ahmed (Assistant Professor) - Mid Career
# INFO:__main__:  - Hilal Ahmed (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,824 - __main__ - INFO -   - Absar Ahmad (Professor) - Senior Career
# INFO:__main__:  - Absar Ahmad (Professor) - Senior Career
# 2025-07-21 06:32:04,825 - __main__ - INFO - ✓ Enhanced point 1d9980b0-eb6c-41dd-92f9-36c57d3c5f07 -> 6 records
# INFO:__main__:✓ Enhanced point 1d9980b0-eb6c-41dd-92f9-36c57d3c5f07 -> 6 records
# 2025-07-21 06:32:04,827 - __main__ - INFO - Processing point 1db5b717-0f07-494a-be47-1b0bffc60005
# INFO:__main__:Processing point 1db5b717-0f07-494a-be47-1b0bffc60005
# 2025-07-21 06:32:04,828 - __main__ - INFO - Using pattern 'basic_entry' - found 6 matches
# INFO:__main__:Using pattern 'basic_entry' - found 6 matches
# 2025-07-21 06:32:04,832 - __main__ - INFO - Found 6 valid faculty records
# INFO:__main__:Found 6 valid faculty records
# 2025-07-21 06:32:04,833 - __main__ - INFO -   - Deepak (Assistant Professor) - Early Career
# INFO:__main__:  - Deepak (Assistant Professor) - Early Career
# 2025-07-21 06:32:04,834 - __main__ - INFO -   - Krishna Reddy (Assistant Professor) - Early Career
# INFO:__main__:  - Krishna Reddy (Assistant Professor) - Early Career
# 2025-07-21 06:32:04,835 - __main__ - INFO -   - Ipsita Saha (Assistant Professor) - Early Career
# INFO:__main__:  - Ipsita Saha (Assistant Professor) - Early Career
# 2025-07-21 06:32:04,836 - __main__ - INFO -   - Soumen Ghosh (Assistant Professor) - Early Career
# INFO:__main__:  - Soumen Ghosh (Assistant Professor) - Early Career
# 2025-07-21 06:32:04,837 - __main__ - INFO -   - Sayak Dutta Gupta (Assistant Professor) - Early Career
# INFO:__main__:  - Sayak Dutta Gupta (Assistant Professor) - Early Career
# 2025-07-21 06:32:04,840 - __main__ - INFO -   - Kannabiran (Assistant Professor) - Early Career
# INFO:__main__:  - Kannabiran (Assistant Professor) - Early Career
# 2025-07-21 06:32:04,842 - __main__ - INFO - ✓ Enhanced point 1db5b717-0f07-494a-be47-1b0bffc60005 -> 6 records
# INFO:__main__:✓ Enhanced point 1db5b717-0f07-494a-be47-1b0bffc60005 -> 6 records
# 2025-07-21 06:32:04,843 - __main__ - INFO - Processing point 1e2ed1bc-c54a-4e0f-ac21-325c56ab216c
# INFO:__main__:Processing point 1e2ed1bc-c54a-4e0f-ac21-325c56ab216c
# 2025-07-21 06:32:04,844 - __main__ - INFO - Using pattern 'pipe_separated' - found 5 matches
# INFO:__main__:Using pattern 'pipe_separated' - found 5 matches
# 2025-07-21 06:32:04,845 - __main__ - INFO - Found 5 valid faculty records
# INFO:__main__:Found 5 valid faculty records
# 2025-07-21 06:32:04,846 - __main__ - INFO -   - Murthy N Haradanahalli (Professor) - Distinguished Career
# INFO:__main__:  - Murthy N Haradanahalli (Professor) - Distinguished Career
# 2025-07-21 06:32:04,847 - __main__ - INFO -   - Vidya Bhushan Maji (Professor) - Senior Career
# INFO:__main__:  - Vidya Bhushan Maji (Professor) - Senior Career
# 2025-07-21 06:32:04,848 - __main__ - INFO -   - Rahul Ratnakar Marathe (Professor) - Senior Career
# INFO:__main__:  - Rahul Ratnakar Marathe (Professor) - Senior Career
# 2025-07-21 06:32:04,849 - __main__ - INFO -   - Murugaiyan Amirthalingam (Assistant Professor) - Mid Career
# INFO:__main__:  - Murugaiyan Amirthalingam (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,850 - __main__ - INFO -   - M Manivannan (Professor) - Distinguished Career
# INFO:__main__:  - M Manivannan (Professor) - Distinguished Career
# 2025-07-21 06:32:04,854 - __main__ - INFO - ✓ Enhanced point 1e2ed1bc-c54a-4e0f-ac21-325c56ab216c -> 5 records
# INFO:__main__:✓ Enhanced point 1e2ed1bc-c54a-4e0f-ac21-325c56ab216c -> 5 records
# 2025-07-21 06:32:04,855 - __main__ - INFO - Processing point 1e81cff2-ace4-4f8f-8c6f-f02766fb9553
# INFO:__main__:Processing point 1e81cff2-ace4-4f8f-8c6f-f02766fb9553
# 2025-07-21 06:32:04,856 - __main__ - INFO - Using pattern 'pipe_separated' - found 4 matches
# INFO:__main__:Using pattern 'pipe_separated' - found 4 matches
# 2025-07-21 06:32:04,857 - __main__ - INFO - Found 4 valid faculty records
# INFO:__main__:Found 4 valid faculty records
# 2025-07-21 06:32:04,859 - __main__ - INFO -   - Nagabhushana Rao Vadlamani (Associate Professor) - Mid Career
# INFO:__main__:  - Nagabhushana Rao Vadlamani (Associate Professor) - Mid Career
# 2025-07-21 06:32:04,862 - __main__ - INFO -   - Jithin John Varghese (Associate Professor) - Mid Career
# INFO:__main__:  - Jithin John Varghese (Associate Professor) - Mid Career
# 2025-07-21 06:32:04,863 - __main__ - INFO -   - Bhaswar Chakrabarti (Assistant Professor) - Mid Career
# INFO:__main__:  - Bhaswar Chakrabarti (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,864 - __main__ - INFO -   - Chandan Sarangi (Assistant Professor) - Mid Career
# INFO:__main__:  - Chandan Sarangi (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,865 - __main__ - INFO - ✓ Enhanced point 1e81cff2-ace4-4f8f-8c6f-f02766fb9553 -> 4 records
# INFO:__main__:✓ Enhanced point 1e81cff2-ace4-4f8f-8c6f-f02766fb9553 -> 4 records
# 2025-07-21 06:32:04,866 - __main__ - INFO - Processing point 1ed40a5b-fac2-4e93-89d9-17d6c6cf87de
# INFO:__main__:Processing point 1ed40a5b-fac2-4e93-89d9-17d6c6cf87de
# 2025-07-21 06:32:04,868 - __main__ - INFO - Using pattern 'basic_entry' - found 2 matches
# INFO:__main__:Using pattern 'basic_entry' - found 2 matches
# 2025-07-21 06:32:04,869 - __main__ - INFO - Found 2 valid faculty records
# INFO:__main__:Found 2 valid faculty records
# 2025-07-21 06:32:04,871 - __main__ - INFO -   - Anupama Rajan (Assistant Professor) - Early Career
# INFO:__main__:  - Anupama Rajan (Assistant Professor) - Early Career
# 2025-07-21 06:32:04,872 - __main__ - INFO -   - Danny Raj M (Assistant Professor) - Early Career
# INFO:__main__:  - Danny Raj M (Assistant Professor) - Early Career
# 2025-07-21 06:32:04,873 - __main__ - INFO - ✓ Enhanced point 1ed40a5b-fac2-4e93-89d9-17d6c6cf87de -> 2 records
# INFO:__main__:✓ Enhanced point 1ed40a5b-fac2-4e93-89d9-17d6c6cf87de -> 2 records
# 2025-07-21 06:32:04,874 - __main__ - INFO - Processing point 1ed7b04b-c857-42cf-badc-d357e207850b
# INFO:__main__:Processing point 1ed7b04b-c857-42cf-badc-d357e207850b
# 2025-07-21 06:32:04,875 - __main__ - INFO - Using pattern 'basic_entry' - found 6 matches
# INFO:__main__:Using pattern 'basic_entry' - found 6 matches
# 2025-07-21 06:32:04,877 - __main__ - INFO - Found 6 valid faculty records
# INFO:__main__:Found 6 valid faculty records
# 2025-07-21 06:32:04,878 - __main__ - INFO -   - Shyam Mohan (Associate Professor) - Mid Career
# INFO:__main__:  - Shyam Mohan (Associate Professor) - Mid Career
# 2025-07-21 06:32:04,879 - __main__ - INFO -   - Arshinder Kaur (Professor) - Senior Career
# INFO:__main__:  - Arshinder Kaur (Professor) - Senior Career
# 2025-07-21 06:32:04,880 - __main__ - INFO -   - R Nirmala (Professor) - Senior Career
# INFO:__main__:  - R Nirmala (Professor) - Senior Career
# 2025-07-21 06:32:04,881 - __main__ - INFO -   - Satyanarayanan (Associate Professor) - Mid Career
# INFO:__main__:  - Satyanarayanan (Associate Professor) - Mid Career
# 2025-07-21 06:32:04,882 - __main__ - INFO -   - Lata Dyaram (Professor) - Senior Career
# INFO:__main__:  - Lata Dyaram (Professor) - Senior Career
# 2025-07-21 06:32:04,883 - __main__ - INFO -   - T N C Anand (Associate Professor) - Senior Career
# INFO:__main__:  - T N C Anand (Associate Professor) - Senior Career
# 2025-07-21 06:32:04,885 - __main__ - INFO - ✓ Enhanced point 1ed7b04b-c857-42cf-badc-d357e207850b -> 6 records
# INFO:__main__:✓ Enhanced point 1ed7b04b-c857-42cf-badc-d357e207850b -> 6 records
# 2025-07-21 06:32:04,886 - __main__ - INFO - Processing point 1f20e5e3-bbb0-4c48-9f31-4dde8f804b86
# INFO:__main__:Processing point 1f20e5e3-bbb0-4c48-9f31-4dde8f804b86
# 2025-07-21 06:32:04,888 - __main__ - INFO - Using pattern 'pipe_separated' - found 5 matches
# INFO:__main__:Using pattern 'pipe_separated' - found 5 matches
# 2025-07-21 06:32:04,889 - __main__ - INFO - Found 5 valid faculty records
# INFO:__main__:Found 5 valid faculty records
# 2025-07-21 06:32:04,890 - __main__ - INFO -   - Misbahur Rahman Warsi (Associate Professor) - Senior Career
# INFO:__main__:  - Misbahur Rahman Warsi (Associate Professor) - Senior Career
# 2025-07-21 06:32:04,892 - __main__ - INFO -   - Nafees Ahmad (Associate Professor) - Senior Career
# INFO:__main__:  - Nafees Ahmad (Associate Professor) - Senior Career
# 2025-07-21 06:32:04,893 - __main__ - INFO -   - M S Jafri (Associate Professor) - Senior Career
# INFO:__main__:  - M S Jafri (Associate Professor) - Senior Career
# 2025-07-21 06:32:04,894 - __main__ - INFO -   - Rehan A Khan (Professor) - Distinguished Career
# INFO:__main__:  - Rehan A Khan (Professor) - Distinguished Career
# 2025-07-21 06:32:04,897 - __main__ - INFO -   - Ekram Khan (Professor) - Distinguished Career
# INFO:__main__:  - Ekram Khan (Professor) - Distinguished Career
# 2025-07-21 06:32:04,898 - __main__ - INFO - ✓ Enhanced point 1f20e5e3-bbb0-4c48-9f31-4dde8f804b86 -> 5 records
# INFO:__main__:✓ Enhanced point 1f20e5e3-bbb0-4c48-9f31-4dde8f804b86 -> 5 records
# 2025-07-21 06:32:04,899 - __main__ - INFO - Processing point 2292c53c-4473-413a-8e6f-4d21aad64612
# INFO:__main__:Processing point 2292c53c-4473-413a-8e6f-4d21aad64612
# 2025-07-21 06:32:04,900 - __main__ - INFO - Using pattern 'basic_entry' - found 6 matches
# INFO:__main__:Using pattern 'basic_entry' - found 6 matches
# 2025-07-21 06:32:04,901 - __main__ - INFO - Found 6 valid faculty records
# INFO:__main__:Found 6 valid faculty records
# 2025-07-21 06:32:04,902 - __main__ - INFO -   - Manu Jaiswal (Professor) - Senior Career
# INFO:__main__:  - Manu Jaiswal (Professor) - Senior Career
# 2025-07-21 06:32:04,904 - __main__ - INFO -   - V Srinivasa (Professor) - Distinguished Career
# INFO:__main__:  - V Srinivasa (Professor) - Distinguished Career
# 2025-07-21 06:32:04,905 - __main__ - INFO -   - John Bosco (Associate Professor) - Senior Career
# INFO:__main__:  - John Bosco (Associate Professor) - Senior Career
# 2025-07-21 06:32:04,906 - __main__ - INFO -   - Shankar Ghosh (Assistant Professor) - Mid Career
# INFO:__main__:  - Shankar Ghosh (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,907 - __main__ - INFO -   - Arul (Professor) - Senior Career
# INFO:__main__:  - Arul (Professor) - Senior Career
# 2025-07-21 06:32:04,908 - __main__ - INFO -   - Satya Sundar (Professor) - Senior Career
# INFO:__main__:  - Satya Sundar (Professor) - Senior Career
# 2025-07-21 06:32:04,909 - __main__ - INFO - ✓ Enhanced point 2292c53c-4473-413a-8e6f-4d21aad64612 -> 6 records
# INFO:__main__:✓ Enhanced point 2292c53c-4473-413a-8e6f-4d21aad64612 -> 6 records
# 2025-07-21 06:32:04,910 - __main__ - INFO - Processing point 237d94eb-8059-4347-ac99-1c20b8a72a91
# INFO:__main__:Processing point 237d94eb-8059-4347-ac99-1c20b8a72a91
# 2025-07-21 06:32:04,911 - __main__ - WARNING - No valid faculty records found for point 237d94eb-8059-4347-ac99-1c20b8a72a91
# WARNING:__main__:No valid faculty records found for point 237d94eb-8059-4347-ac99-1c20b8a72a91
# 2025-07-21 06:32:04,912 - __main__ - INFO - Processing point 24de7ef1-813e-4488-a0d6-32e01114be03
# INFO:__main__:Processing point 24de7ef1-813e-4488-a0d6-32e01114be03
# 2025-07-21 06:32:04,913 - __main__ - INFO - Using pattern 'basic_entry' - found 6 matches
# INFO:__main__:Using pattern 'basic_entry' - found 6 matches
# 2025-07-21 06:32:04,915 - __main__ - INFO - Found 6 valid faculty records
# INFO:__main__:Found 6 valid faculty records
# 2025-07-21 06:32:04,916 - __main__ - INFO -   - Najam Sardar (Associate Professor) - Senior Career
# INFO:__main__:  - Najam Sardar (Associate Professor) - Senior Career
# 2025-07-21 06:32:04,917 - __main__ - INFO -   - Muhammad (Assistant Professor) - Mid Career
# INFO:__main__:  - Muhammad (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,920 - __main__ - INFO -   - Faisal Talib (Professor) - Distinguished Career
# INFO:__main__:  - Faisal Talib (Professor) - Distinguished Career
# 2025-07-21 06:32:04,921 - __main__ - INFO -   - Imtiaz Ashraf (Professor) - Distinguished Career
# INFO:__main__:  - Imtiaz Ashraf (Professor) - Distinguished Career
# 2025-07-21 06:32:04,922 - __main__ - INFO -   - Azra Parveen (Assistant Professor) - Mid Career
# INFO:__main__:  - Azra Parveen (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,925 - __main__ - INFO -   - Mohammed Ali (Professor) - Senior Career
# INFO:__main__:  - Mohammed Ali (Professor) - Senior Career
# 2025-07-21 06:32:04,926 - __main__ - INFO - ✓ Enhanced point 24de7ef1-813e-4488-a0d6-32e01114be03 -> 6 records
# INFO:__main__:✓ Enhanced point 24de7ef1-813e-4488-a0d6-32e01114be03 -> 6 records
# 2025-07-21 06:32:04,927 - __main__ - INFO - Processing point 24fb96be-bb8b-472e-9162-c22d5a25fff6
# INFO:__main__:Processing point 24fb96be-bb8b-472e-9162-c22d5a25fff6
# 2025-07-21 06:32:04,931 - __main__ - INFO - Using pattern 'pipe_separated' - found 5 matches
# INFO:__main__:Using pattern 'pipe_separated' - found 5 matches
# 2025-07-21 06:32:04,932 - __main__ - INFO - Found 5 valid faculty records
# INFO:__main__:Found 5 valid faculty records
# 2025-07-21 06:32:04,933 - __main__ - INFO -   - P V Manivannan (Associate Professor) - Mid Career
# INFO:__main__:  - P V Manivannan (Associate Professor) - Mid Career
# 2025-07-21 06:32:04,934 - __main__ - INFO -   - M Senthil Murugan (Assistant Professor) - Mid Career
# INFO:__main__:  - M Senthil Murugan (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,935 - __main__ - INFO -   - Arun K Tangirala (Professor) - Distinguished Career
# INFO:__main__:  - Arun K Tangirala (Professor) - Distinguished Career
# 2025-07-21 06:32:04,936 - __main__ - INFO -   - R K Amit (Professor) - Senior Career
# INFO:__main__:  - R K Amit (Professor) - Senior Career
# 2025-07-21 06:32:04,940 - __main__ - INFO -   - Puduru Viswanadha Reddy (Assistant Professor) - Mid Career
# INFO:__main__:  - Puduru Viswanadha Reddy (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,942 - __main__ - INFO - ✓ Enhanced point 24fb96be-bb8b-472e-9162-c22d5a25fff6 -> 5 records
# INFO:__main__:✓ Enhanced point 24fb96be-bb8b-472e-9162-c22d5a25fff6 -> 5 records
# 2025-07-21 06:32:04,943 - __main__ - INFO - Processing point 26131c42-fa71-4378-9510-ca79fab8b42c
# INFO:__main__:Processing point 26131c42-fa71-4378-9510-ca79fab8b42c
# 2025-07-21 06:32:04,944 - __main__ - INFO - Using pattern 'basic_entry' - found 6 matches
# INFO:__main__:Using pattern 'basic_entry' - found 6 matches
# 2025-07-21 06:32:04,945 - __main__ - INFO - Found 6 valid faculty records
# INFO:__main__:Found 6 valid faculty records
# 2025-07-21 06:32:04,946 - __main__ - INFO -   - Dawood (Associate Professor) - Mid Career
# INFO:__main__:  - Dawood (Associate Professor) - Mid Career
# 2025-07-21 06:32:04,947 - __main__ - INFO -   - Ragunathan (Professor) - Senior Career
# INFO:__main__:  - Ragunathan (Professor) - Senior Career
# 2025-07-21 06:32:04,952 - __main__ - INFO -   - Panchanana Khuntia (Assistant Professor) - Mid Career
# INFO:__main__:  - Panchanana Khuntia (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,953 - __main__ - INFO -   - V Subramanya (Professor) - Distinguished Career
# INFO:__main__:  - V Subramanya (Professor) - Distinguished Career
# 2025-07-21 06:32:04,954 - __main__ - INFO -   - Indumathi (Professor) - Distinguished Career
# INFO:__main__:  - Indumathi (Professor) - Distinguished Career
# 2025-07-21 06:32:04,955 - __main__ - INFO -   - Satyajit Roy (Professor) - Distinguished Career
# INFO:__main__:  - Satyajit Roy (Professor) - Distinguished Career
# 2025-07-21 06:32:04,956 - __main__ - INFO - ✓ Enhanced point 26131c42-fa71-4378-9510-ca79fab8b42c -> 6 records
# INFO:__main__:✓ Enhanced point 26131c42-fa71-4378-9510-ca79fab8b42c -> 6 records
# 2025-07-21 06:32:04,957 - __main__ - INFO - Processing point 276413dc-d9c1-4332-bf9f-532969dd591e
# INFO:__main__:Processing point 276413dc-d9c1-4332-bf9f-532969dd591e
# 2025-07-21 06:32:04,959 - __main__ - WARNING - No valid faculty records found for point 276413dc-d9c1-4332-bf9f-532969dd591e
# WARNING:__main__:No valid faculty records found for point 276413dc-d9c1-4332-bf9f-532969dd591e
# 2025-07-21 06:32:04,960 - __main__ - INFO - Processing point 27d66f31-abdb-4d26-9331-13ec3bfb5b02
# INFO:__main__:Processing point 27d66f31-abdb-4d26-9331-13ec3bfb5b02
# 2025-07-21 06:32:04,961 - __main__ - INFO - Using pattern 'pipe_separated' - found 1 matches
# INFO:__main__:Using pattern 'pipe_separated' - found 1 matches
# 2025-07-21 06:32:04,962 - __main__ - INFO - Found 1 valid faculty records
# INFO:__main__:Found 1 valid faculty records
# 2025-07-21 06:32:04,964 - __main__ - INFO -   - Sriram R (Assistant Professor) - Mid Career
# INFO:__main__:  - Sriram R (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,965 - __main__ - INFO - ✓ Enhanced point 27d66f31-abdb-4d26-9331-13ec3bfb5b02 -> 1 records
# INFO:__main__:✓ Enhanced point 27d66f31-abdb-4d26-9331-13ec3bfb5b02 -> 1 records
# 2025-07-21 06:32:04,966 - __main__ - INFO - Processing point 290c7acd-de05-4ab4-9688-b30264ace7d8
# INFO:__main__:Processing point 290c7acd-de05-4ab4-9688-b30264ace7d8
# 2025-07-21 06:32:04,967 - __main__ - INFO - Using pattern 'basic_entry' - found 7 matches
# INFO:__main__:Using pattern 'basic_entry' - found 7 matches
# 2025-07-21 06:32:04,968 - __main__ - INFO - Found 7 valid faculty records
# INFO:__main__:Found 7 valid faculty records
# 2025-07-21 06:32:04,969 - __main__ - INFO -   - Sathyan Subbiah (Professor) - Senior Career
# INFO:__main__:  - Sathyan Subbiah (Professor) - Senior Career
# 2025-07-21 06:32:04,970 - __main__ - INFO -   - G Sekar (Professor) - Distinguished Career
# INFO:__main__:  - G Sekar (Professor) - Distinguished Career
# 2025-07-21 06:32:04,971 - __main__ - INFO -   - S Balaji (Professor) - Distinguished Career
# INFO:__main__:  - S Balaji (Professor) - Distinguished Career
# 2025-07-21 06:32:04,972 - __main__ - INFO -   - Sriram (Assistant Professor) - Mid Career
# INFO:__main__:  - Sriram (Assistant Professor) - Mid Career
# 2025-07-21 06:32:04,978 - __main__ - INFO -   - M Suresh Babu (Professor) - Senior Career
# INFO:__main__:  - M Suresh Babu (Professor) - Senior Career
# 2025-07-21 06:32:04,979 - __main__ - INFO -   - G Radhakrishna (Professor) - Senior Career
# INFO:__main__:  - G Radhakrishna (Professor) - Senior Career
# 2025-07-21 06:32:04,980 - __main__ - INFO -   - G Rajesh (Professor) - Senior Career
# INFO:__main__:  - G Rajesh (Professor) - Senior Career
# 2025-07-21 06:32:04,981 - __main__ - INFO - ✓ Enhanced point 290c7acd-de05-4ab4-9688-b30264ace7d8 -> 7 records
# INFO:__main__:✓ Enhanced point 290c7acd-de05-4ab4-9688-b30264ace7d8 -> 7 records
# 2025-07-21 06:32:04,982 - __main__ - INFO - Processing point 293502df-6bf5-461f-ac27-bb504f1171c9
# INFO:__main__:Processing point 293502df-6bf5-461f-ac27-bb504f1171c9
# 2025-07-21 06:32:04,983 - __main__ - INFO - Using pattern 'pipe_separated' - found 5 matches
# INFO:__main__:Using pattern 'pipe_separated' - found 5 matches
# 2025-07-21 06:32:04,985 - __main__ - INFO - Found 5 valid faculty records
# INFO:__main__:Found 5 valid faculty records
# 2025-07-21 06:32:04,986 - __main__ - INFO -   - Balaji Narasimhan (Associate Professor) - Senior Career
# INFO:__main__:  - Balaji Narasimhan (Associate Professor) - Senior Career
# 2025-07-21 06:32:04,989 - __main__ - INFO -   - Rajesh Kumar (Professor) - Senior Career
# INFO:__main__:  - Rajesh Kumar (Professor) - Senior Career
# 2025-07-21 06:32:04,990 - __main__ - INFO -   - G L Samuel (Professor) - Distinguished Career
# INFO:__main__:  - G L Samuel (Professor) - Distinguished Career
# 2025-07-21 06:32:04,991 - __main__ - INFO -   - S T G Raghukanth (Professor) - Senior Career
# INFO:__main__:  - S T G Raghukanth (Professor) - Senior Career
# 2025-07-21 06:32:04,992 - __main__ - INFO -   - Mahaveer Kumar Jain (Associate Professor) - Senior Career
# INFO:__main__:  - Mahaveer Kumar Jain (Associate Professor) - Senior Career
# 2025-07-21 06:32:04,994 - __main__ - INFO - ✓ Enhanced point 293502df-6bf5-461f-ac27-bb504f1171c9 -> 5 records
# INFO:__main__:✓ Enhanced point 293502df-6bf5-461f-ac27-bb504f1171c9 -> 5 records
# 2025-07-21 06:32:04,995 - __main__ - INFO - Processing point 2a681bf7-a779-4203-8979-3aa184a64c77
# INFO:__main__:Processing point 2a681bf7-a779-4203-8979-3aa184a64c77
# 2025-07-21 06:32:04,999 - __main__ - INFO - Using pattern 'basic_entry' - found 6 matches
# INFO:__main__:Using pattern 'basic_entry' - found 6 matches
# 2025-07-21 06:32:05,000 - __main__ - INFO - Found 6 valid faculty records
# INFO:__main__:Found 6 valid faculty records
# 2025-07-21 06:32:05,001 - __main__ - INFO -   - Palaniselvam T (Assistant Professor) - Early Career
# INFO:__main__:  - Palaniselvam T (Assistant Professor) - Early Career
# 2025-07-21 06:32:05,002 - __main__ - INFO -   - Meiyappan (Assistant Professor) - Early Career
# INFO:__main__:  - Meiyappan (Assistant Professor) - Early Career
# 2025-07-21 06:32:05,003 - __main__ - INFO -   - Nitin Muralidharan (Assistant Professor) - Early Career
# INFO:__main__:  - Nitin Muralidharan (Assistant Professor) - Early Career
# 2025-07-21 06:32:05,004 - __main__ - INFO -   - Thanggoulen Kipgen (Assistant Professor) - Early Career
# INFO:__main__:  - Thanggoulen Kipgen (Assistant Professor) - Early Career
# 2025-07-21 06:32:05,005 - __main__ - INFO -   - Mathangi (Associate Professor) - Mid Career
# INFO:__main__:  - Mathangi (Associate Professor) - Mid Career
# 2025-07-21 06:32:05,007 - __main__ - INFO -   - B Kalyan Kumar (Professor) - Senior Career
# INFO:__main__:  - B Kalyan Kumar (Professor) - Senior Career
# 2025-07-21 06:32:05,008 - __main__ - INFO - ✓ Enhanced point 2a681bf7-a779-4203-8979-3aa184a64c77 -> 6 records
# INFO:__main__:✓ Enhanced point 2a681bf7-a779-4203-8979-3aa184a64c77 -> 6 records
# 2025-07-21 06:32:05,009 - __main__ - INFO - Processing point 2bee10c2-bc5c-474d-8b23-892e8edbc771
# INFO:__main__:Processing point 2bee10c2-bc5c-474d-8b23-892e8edbc771
# 2025-07-21 06:32:05,010 - __main__ - INFO - Using pattern 'basic_entry' - found 5 matches
# INFO:__main__:Using pattern 'basic_entry' - found 5 matches
# 2025-07-21 06:32:05,012 - __main__ - INFO - Found 5 valid faculty records
# INFO:__main__:Found 5 valid faculty records
# 2025-07-21 06:32:05,013 - __main__ - INFO -   - Arun Kumar (Professor) - Senior Career
# INFO:__main__:  - Arun Kumar (Professor) - Senior Career
# 2025-07-21 06:32:05,014 - __main__ - INFO -   - R Swarnalatha (Professor) - Distinguished Career
# INFO:__main__:  - R Swarnalatha (Professor) - Distinguished Career
# ...
# 2025-07-21 06:32:08,355 - __main__ - INFO - Found 6 valid faculty records
# INFO:__main__:Found 6 valid faculty records
# 2025-07-21 06:32:08,356 - __main__ - INFO -   - R Balaji (Professor) - Senior Career
# INFO:__main__:  - R Balaji (Professor) - Senior Career
# 2025-07-21 06:32:08,357 - __main__ - INFO -   - Palaniswamy (Professor) - Senior Career
# INFO:__main__:  - Palaniswamy (Professor) - Senior Career
# 2025-07-21 06:32:08,358 - __main__ - INFO -   - M Ramanathan (Professor) - Senior Career
# INFO:__main__:  - M Ramanathan (Professor) - Senior Career
# 2025-07-21 06:32:08,359 - __main__ - INFO -   - Alagappan P (Assistant Professor) - Mid Career
# INFO:__main__:  - Alagappan P (Assistant Professor) - Mid Career
# 2025-07-21 06:32:08,360 - __main__ - INFO -   - Venkatraman (Assistant Professor) - Mid Career
# INFO:__main__:  - Venkatraman (Assistant Professor) - Mid Career
# 2025-07-21 06:32:08,361 - __main__ - INFO -   - Surender Singh (Assistant Professor) - Mid Career
# INFO:__main__:  - Surender Singh (Assistant Professor) - Mid Career
# 2025-07-21 06:32:08,363 - __main__ - INFO - ✓ Enhanced point f830b75c-d970-47f9-b0eb-ab2187d1d045 -> 6 records
# INFO:__main__:✓ Enhanced point f830b75c-d970-47f9-b0eb-ab2187d1d045 -> 6 records
# 2025-07-21 06:32:08,364 - __main__ - INFO - Processing point f8c2d40c-71ac-43b8-b4ea-f2856445ca9b
# INFO:__main__:Processing point f8c2d40c-71ac-43b8-b4ea-f2856445ca9b
# 2025-07-21 06:32:08,365 - __main__ - INFO - Found 1 valid faculty records
# INFO:__main__:Found 1 valid faculty records
# 2025-07-21 06:32:08,366 - __main__ - INFO -   - Yes (Professor) - Senior Career
# INFO:__main__:  - Yes (Professor) - Senior Career
# 2025-07-21 06:32:08,367 - __main__ - INFO - ✓ Enhanced point f8c2d40c-71ac-43b8-b4ea-f2856445ca9b -> 1 records
# INFO:__main__:✓ Enhanced point f8c2d40c-71ac-43b8-b4ea-f2856445ca9b -> 1 records
# 2025-07-21 06:32:08,368 - __main__ - INFO - Processing point f8c60372-f4e1-40e2-bbf6-3a467ae62c71
# INFO:__main__:Processing point f8c60372-f4e1-40e2-bbf6-3a467ae62c71
# 2025-07-21 06:32:08,369 - __main__ - INFO - Using pattern 'pipe_separated' - found 2 matches
# INFO:__main__:Using pattern 'pipe_separated' - found 2 matches
# 2025-07-21 06:32:08,370 - __main__ - INFO - Found 2 valid faculty records
# INFO:__main__:Found 2 valid faculty records
# 2025-07-21 06:32:08,371 - __main__ - INFO -   - Shyama Prasad Das (Assistant Professor) - Mid Career
# INFO:__main__:  - Shyama Prasad Das (Assistant Professor) - Mid Career
# 2025-07-21 06:32:08,372 - __main__ - INFO -   - B S Murty (Professor) - Distinguished Career
# INFO:__main__:  - B S Murty (Professor) - Distinguished Career
# 2025-07-21 06:32:08,373 - __main__ - INFO - ✓ Enhanced point f8c60372-f4e1-40e2-bbf6-3a467ae62c71 -> 2 records
# INFO:__main__:✓ Enhanced point f8c60372-f4e1-40e2-bbf6-3a467ae62c71 -> 2 records
# 2025-07-21 06:32:08,374 - __main__ - INFO - Processing point fa4bc9cd-70ef-4d35-9ab9-d2990830ecd9
# INFO:__main__:Processing point fa4bc9cd-70ef-4d35-9ab9-d2990830ecd9
# 2025-07-21 06:32:08,375 - __main__ - INFO - Using pattern 'pipe_separated' - found 5 matches
# INFO:__main__:Using pattern 'pipe_separated' - found 5 matches
# 2025-07-21 06:32:08,376 - __main__ - INFO - Found 5 valid faculty records
# INFO:__main__:Found 5 valid faculty records
# 2025-07-21 06:32:08,377 - __main__ - INFO -   - M Z A Rafiquee (Professor) - Distinguished Career
# INFO:__main__:  - M Z A Rafiquee (Professor) - Distinguished Career
# 2025-07-21 06:32:08,379 - __main__ - INFO -   - Iftekhar Ahmad (Assistant Professor) - Mid Career
# INFO:__main__:  - Iftekhar Ahmad (Assistant Professor) - Mid Career
# 2025-07-21 06:32:08,380 - __main__ - INFO -   - Saleem Anwar Khan (Professor) - Senior Career
# INFO:__main__:  - Saleem Anwar Khan (Professor) - Senior Career
# 2025-07-21 06:32:08,381 - __main__ - INFO -   - Tazyeen Ahmad (Professor) - Distinguished Career
# INFO:__main__:  - Tazyeen Ahmad (Professor) - Distinguished Career
# 2025-07-21 06:32:08,382 - __main__ - INFO -   - Y U Khan (Professor) - Distinguished Career
# INFO:__main__:  - Y U Khan (Professor) - Distinguished Career
# 2025-07-21 06:32:08,383 - __main__ - INFO - ✓ Enhanced point fa4bc9cd-70ef-4d35-9ab9-d2990830ecd9 -> 5 records
# INFO:__main__:✓ Enhanced point fa4bc9cd-70ef-4d35-9ab9-d2990830ecd9 -> 5 records
# 2025-07-21 06:32:08,384 - __main__ - INFO - Processing point fa55ab49-9cc0-453a-b3a3-6d6b0b570364
# INFO:__main__:Processing point fa55ab49-9cc0-453a-b3a3-6d6b0b570364
# 2025-07-21 06:32:08,385 - __main__ - WARNING - No valid faculty records found for point fa55ab49-9cc0-453a-b3a3-6d6b0b570364
# WARNING:__main__:No valid faculty records found for point fa55ab49-9cc0-453a-b3a3-6d6b0b570364
# 2025-07-21 06:32:08,388 - __main__ - INFO - Processing point fafda1f9-6f4e-4c12-9af0-7a7ffac9cb39
# INFO:__main__:Processing point fafda1f9-6f4e-4c12-9af0-7a7ffac9cb39
# 2025-07-21 06:32:08,389 - __main__ - INFO - Using pattern 'basic_entry' - found 2 matches
# INFO:__main__:Using pattern 'basic_entry' - found 2 matches
# 2025-07-21 06:32:08,390 - __main__ - INFO - Found 2 valid faculty records
# INFO:__main__:Found 2 valid faculty records
# 2025-07-21 06:32:08,391 - __main__ - INFO -   - I H Farooqi (Professor) - Distinguished Career
# INFO:__main__:  - I H Farooqi (Professor) - Distinguished Career
# 2025-07-21 06:32:08,392 - __main__ - INFO -   - M Fazle Azeem (Professor) - Distinguished Career
# INFO:__main__:  - M Fazle Azeem (Professor) - Distinguished Career
# 2025-07-21 06:32:08,393 - __main__ - INFO - ✓ Enhanced point fafda1f9-6f4e-4c12-9af0-7a7ffac9cb39 -> 2 records
# INFO:__main__:✓ Enhanced point fafda1f9-6f4e-4c12-9af0-7a7ffac9cb39 -> 2 records
# 2025-07-21 06:32:08,397 - __main__ - INFO - Processing point fb54e210-f4a2-43ea-b381-fd761be8fb12
# INFO:__main__:Processing point fb54e210-f4a2-43ea-b381-fd761be8fb12
# 2025-07-21 06:32:08,398 - __main__ - INFO - Using pattern 'pipe_separated' - found 2 matches
# INFO:__main__:Using pattern 'pipe_separated' - found 2 matches
# 2025-07-21 06:32:08,399 - __main__ - INFO - Found 2 valid faculty records
# INFO:__main__:Found 2 valid faculty records
# 2025-07-21 06:32:08,400 - __main__ - INFO -   - M Tabish (Assistant Professor) - Early Career
# INFO:__main__:  - M Tabish (Assistant Professor) - Early Career
# 2025-07-21 06:32:08,401 - __main__ - INFO -   - Mohd Faisal Jalil (Assistant Professor) - Early Career
# INFO:__main__:  - Mohd Faisal Jalil (Assistant Professor) - Early Career
# 2025-07-21 06:32:08,402 - __main__ - INFO - ✓ Enhanced point fb54e210-f4a2-43ea-b381-fd761be8fb12 -> 2 records
# INFO:__main__:✓ Enhanced point fb54e210-f4a2-43ea-b381-fd761be8fb12 -> 2 records
# 2025-07-21 06:32:08,403 - __main__ - INFO - Processing point ff68297d-1540-4ff6-b3ab-6cb67bbbb6b2
# INFO:__main__:Processing point ff68297d-1540-4ff6-b3ab-6cb67bbbb6b2
# 2025-07-21 06:32:08,404 - __main__ - WARNING - No valid faculty records found for point ff68297d-1540-4ff6-b3ab-6cb67bbbb6b2
# WARNING:__main__:No valid faculty records found for point ff68297d-1540-4ff6-b3ab-6cb67bbbb6b2
# 2025-07-21 06:32:08,405 - __main__ - INFO - Processing point ffb2d95d-495e-468c-9fbe-bd960692a82b
# INFO:__main__:Processing point ffb2d95d-495e-468c-9fbe-bd960692a82b
# 2025-07-21 06:32:08,407 - __main__ - INFO - Using pattern 'basic_entry' - found 6 matches
# INFO:__main__:Using pattern 'basic_entry' - found 6 matches
# 2025-07-21 06:32:08,408 - __main__ - INFO - Found 6 valid faculty records
# INFO:__main__:Found 6 valid faculty records
# 2025-07-21 06:32:08,409 - __main__ - INFO -   - Prabat Ranjan (Associate Professor) - Mid Career
# INFO:__main__:  - Prabat Ranjan (Associate Professor) - Mid Career
# 2025-07-21 06:32:08,410 - __main__ - INFO -   - N Harish Kumar (Professor) - Distinguished Career
# INFO:__main__:  - N Harish Kumar (Professor) - Distinguished Career
# 2025-07-21 06:32:08,411 - __main__ - INFO -   - V Babu (Professor) - Distinguished Career
# INFO:__main__:  - V Babu (Professor) - Distinguished Career
# 2025-07-21 06:32:08,413 - __main__ - INFO -   - Ganapathy (Professor) - Senior Career
# INFO:__main__:  - Ganapathy (Professor) - Senior Career
# 2025-07-21 06:32:08,418 - __main__ - INFO -   - Sanjib Senapati (Professor) - Senior Career
# INFO:__main__:  - Sanjib Senapati (Professor) - Senior Career
# 2025-07-21 06:32:08,419 - __main__ - INFO -   - Santosh Kumar (Assistant Professor) - Mid Career
# INFO:__main__:  - Santosh Kumar (Assistant Professor) - Mid Career
# 2025-07-21 06:32:08,420 - __main__ - INFO - ✓ Enhanced point ffb2d95d-495e-468c-9fbe-bd960692a82b -> 6 records
# INFO:__main__:✓ Enhanced point ffb2d95d-495e-468c-9fbe-bd960692a82b -> 6 records
# 2025-07-21 06:32:08,421 - __main__ - INFO - Upserting 363 enhanced points...
# INFO:__main__:Upserting 363 enhanced points...
# 2025-07-21 06:32:09,867 - __main__ - INFO - ✓ Successfully upserted enhanced points
# INFO:__main__:✓ Successfully upserted enhanced points
# 2025-07-21 06:32:09,869 - __main__ - INFO - Deleting 325 original points...
# INFO:__main__:Deleting 325 original points...
# 2025-07-21 06:32:09,945 - __main__ - INFO - ✓ Successfully deleted original points
# INFO:__main__:✓ Successfully deleted original points
# 2025-07-21 06:32:09,947 - __main__ - INFO -
# ============================================================
# INFO:__main__:
# ============================================================
# 2025-07-21 06:32:09,948 - __main__ - INFO - ENHANCED FACULTY DATA PROCESSING REPORT
# INFO:__main__:ENHANCED FACULTY DATA PROCESSING REPORT
# 2025-07-21 06:32:09,950 - __main__ - INFO - ============================================================
# INFO:__main__:============================================================
# 2025-07-21 06:32:09,951 - __main__ - INFO - Total Points Processed: 340
# INFO:__main__:Total Points Processed: 340
# 2025-07-21 06:32:09,953 - __main__ - INFO - Successfully Parsed: 325
# INFO:__main__:Successfully Parsed: 325
# 2025-07-21 06:32:09,957 - __main__ - INFO - Points Enhanced: 325
# INFO:__main__:Points Enhanced: 325
# 2025-07-21 06:32:09,958 - __main__ - INFO - Original Points Deleted: 325
# INFO:__main__:Original Points Deleted: 325
# 2025-07-21 06:32:09,959 - __main__ - INFO - Faculty Records Found: 1344
# INFO:__main__:Faculty Records Found: 1344
# 2025-07-21 06:32:09,961 - __main__ - INFO - Success Rate: 95.59%
# INFO:__main__:Success Rate: 95.59%
# 2025-07-21 06:32:09,965 - __main__ - INFO -
# Designation Distribution:
# INFO:__main__:
# Designation Distribution:
# 2025-07-21 06:32:09,966 - __main__ - INFO -   Professor: 762
# INFO:__main__:  Professor: 762
# 2025-07-21 06:32:09,970 - __main__ - INFO -   Assistant Professor: 424
# INFO:__main__:  Assistant Professor: 424
# 2025-07-21 06:32:09,971 - __main__ - INFO -   Associate Professor: 158
# INFO:__main__:  Associate Professor: 158
# 2025-07-21 06:32:09,972 - __main__ - INFO -
# Qualification Distribution:
# INFO:__main__:
# Qualification Distribution:
# 2025-07-21 06:32:09,974 - __main__ - INFO -   Ph.D: 1305
# INFO:__main__:  Ph.D: 1305
# 2025-07-21 06:32:09,975 - __main__ - INFO -   M.Tech: 30
# INFO:__main__:  M.Tech: 30
# 2025-07-21 06:32:09,976 - __main__ - INFO -   B.Tech: 3
# INFO:__main__:  B.Tech: 3
# 2025-07-21 06:32:09,978 - __main__ - INFO -   LLM: 1
# INFO:__main__:  LLM: 1
# 2025-07-21 06:32:09,979 - __main__ - INFO - ============================================================
# INFO:__main__:============================================================
# 2025-07-21 06:32:09,980 - __main__ - INFO - Enhanced faculty data cleaning process completed!
# INFO:__main__:Enhanced faculty data cleaning process completed!
# 2025-07-21 06:32:09,994 - __main__ - INFO - Verifying enhancements...
# INFO:__main__:Verifying enhancements...
# 2025-07-21 06:32:10,002 - __main__ - INFO - Fetching faculty data with optimized filters...
# INFO:__main__:Fetching faculty data with optimized filters...
# 2025-07-21 06:32:10,077 - __main__ - ERROR - Error fetching data: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Index required but not found for \\"content_type\\" of one of the following types: [keyword]. Help: Create an index for this key or use a different filter."},"time":7 ...'
# ERROR:__main__:Error fetching data: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Index required but not found for \\"content_type\\" of one of the following types: [keyword]. Help: Create an index for this key or use a different filter."},"time":7 ...'
# 2025-07-21 06:32:10,078 - __main__ - INFO - Using fallback method for data fetching...
# INFO:__main__:Using fallback method for data fetching...
# 2025-07-21 06:32:10,710 - __main__ - INFO -
# ==================================================
# INFO:__main__:
# ==================================================
# 2025-07-21 06:32:10,712 - __main__ - INFO - ENHANCEMENT VERIFICATION REPORT
# INFO:__main__:ENHANCEMENT VERIFICATION REPORT
# 2025-07-21 06:32:10,713 - __main__ - INFO - ==================================================
# INFO:__main__:==================================================
# 2025-07-21 06:32:10,714 - __main__ - INFO - Total Enhanced Points: 378
# INFO:__main__:Total Enhanced Points: 378
# 2025-07-21 06:32:10,715 - __main__ - INFO - Average Quality Score: 95.5
# INFO:__main__:Average Quality Score: 95.5
# 2025-07-21 06:32:10,717 - __main__ - INFO - Total Faculty Records: 1610
# INFO:__main__:Total Faculty Records: 1610
# 2025-07-21 06:32:10,718 - __main__ - INFO - Complete Profiles: 1605
# INFO:__main__:Complete Profiles: 1605
# 2025-07-21 06:32:10,719 - __main__ - INFO - Partial Profiles: 5
# INFO:__main__:Partial Profiles: 5
# 2025-07-21 06:32:10,720 - __main__ - INFO -
# Career Stage Distribution:
# INFO:__main__:
# Career Stage Distribution:
# 2025-07-21 06:32:10,722 - __main__ - INFO -   Senior Career: 608
# INFO:__main__:  Senior Career: 608
# 2025-07-21 06:32:10,723 - __main__ - INFO -   Distinguished Career: 455
# INFO:__main__:  Distinguished Career: 455
# 2025-07-21 06:32:10,724 - __main__ - INFO -   Mid Career: 412
# INFO:__main__:  Mid Career: 412
# 2025-07-21 06:32:10,725 - __main__ - INFO -   Early Career: 135
# INFO:__main__:  Early Career: 135
# 2025-07-21 06:32:10,726 - __main__ - INFO -
# Location Coverage:
# INFO:__main__:
# Location Coverage:
# 2025-07-21 06:32:10,727 - __main__ - INFO -   Chennai: 1237
# INFO:__main__:  Chennai: 1237
# 2025-07-21 06:32:10,728 - __main__ - INFO -   Aligarh: 373
# INFO:__main__:  Aligarh: 373
# 2025-07-21 06:32:10,728 - __main__ - INFO - ==================================================
# INFO:__main__:==================================================
# 2025-07-21 06:32:10,734 - __main__ - INFO - Exporting enhanced faculty data to enhanced_faculty_data.json...
# INFO:__main__:Exporting enhanced faculty data to enhanced_faculty_data.json...
# 2025-07-21 06:32:10,738 - __main__ - INFO - Fetching faculty data with optimized filters...
# INFO:__main__:Fetching faculty data with optimized filters...
# 2025-07-21 06:32:10,808 - __main__ - ERROR - Error fetching data: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Index required but not found for \\"content_type\\" of one of the following types: [keyword]. Help: Create an index for this key or use a different filter."},"time":3 ...'
# ERROR:__main__:Error fetching data: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Bad request: Index required but not found for \\"content_type\\" of one of the following types: [keyword]. Help: Create an index for this key or use a different filter."},"time":3 ...'
# 2025-07-21 06:32:10,810 - __main__ - INFO - Using fallback method for data fetching...
# INFO:__main__:Using fallback method for data fetching...
# 2025-07-21 06:32:11,234 - __main__ - INFO - ✓ Successfully exported 363 enhanced faculty records
# INFO:__main__:✓ Successfully exported 363 enhanced faculty records
# 2025-07-21 06:32:11,242 - __main__ - INFO - All processing completed successfully!
# INFO:__main__:All processing completed successfully!
# 2025-07-21 06:32:11,243 - __main__ - INFO - Enhanced data exported to: enhanced_faculty_data.json
# INFO:__main__:Enhanced data exported to: enhanced_faculty_data.json
