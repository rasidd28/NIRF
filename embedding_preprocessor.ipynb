# %%
import os
import re
import json
import pandas as pd
from pathlib import Path
from collections import defaultdict
from datetime import datetime
import hashlib

class EfficientTextProcessor:
    def __init__(self, input_folder, output_folder=None):
        self.input_path = Path(input_folder)
        self.output_path = Path(output_folder) if output_folder else Path(f"{input_folder}_processed")
        self.stats = {'files': 0, 'duplicates': 0, 'chunks': 0}
        self.results = []
        
        # Combined patterns for efficiency
        self.section_patterns = [
            (r'(?i)(student|admission|enrollment)', 'Student Information'),
            (r'(?i)(placement|job|career)', 'Placement & Career'),
            (r'(?i)(faculty|staff|teacher)', 'Faculty Information'),
            (r'(?i)(infrastructure|facility|building)', 'Infrastructure'),
            (r'(?i)(financial|fee|budget)', 'Financial Information'),
            (r'(?i)(academic|curriculum|course)', 'Academic Information'),
            (r'(?i)(research|publication)', 'Research'),
            (r'(?i)(library|books)', 'Library'),
            (r'(?i)(laboratory|lab)', 'Laboratory'),
            (r'(?i)(examination|exam|result)', 'Examination'),
            (r'(?i)(quality|accreditation)', 'Quality Assurance')
        ]
        
        self.cleanup_patterns = [
            (r'file\s+content\s+(begin|end)', ''),
            (r'page\s+\d+(\s+of\s+\d+)?', ''),
            (r'generated\s+on.*?\d{4}', ''),
            (r'copyright.*?\d{4}', ''),
            (r'^\s*[|\-=]+\s*$', ''),
            (r'(\d+)\s*\(\s*([^)]+)\s*\)', r'\1'),  # Remove word numbers in parentheses
            (r'\b(?:one|two|three|four|five|six|seven|eight|nine|ten)\b', lambda m: str(self.word_to_num(m.group()))),
        ]
        
        self.word_nums = {'one': '1', 'two': '2', 'three': '3', 'four': '4', 'five': '5', 
                         'six': '6', 'seven': '7', 'eight': '8', 'nine': '9', 'ten': '10'}

    def word_to_num(self, word):
        return self.word_nums.get(word.lower(), word)

    def clean_text(self, text):
        """Apply all cleaning operations in one pass"""
        for pattern, replacement in self.cleanup_patterns:
            if callable(replacement):
                text = re.sub(pattern, replacement, text, flags=re.IGNORECASE)
            else:
                text = re.sub(pattern, replacement, text, flags=re.IGNORECASE)
        
        # Remove duplicates by line hashing
        lines = text.split('\n')
        seen_hashes = set()
        unique_lines = []
        
        for line in lines:
            line = line.strip()
            if line:
                line_hash = hashlib.md5(line.encode()).hexdigest()
                if line_hash not in seen_hashes:
                    unique_lines.append(line)
                    seen_hashes.add(line_hash)
                else:
                    self.stats['duplicates'] += 1
        
        return '\n'.join(unique_lines)

    def create_chunks(self, text, filename):
        """Create chunks based on section patterns or size"""
        chunks = []
        lines = text.split('\n')
        current_section = 'General'
        current_content = []
        
        for line in lines:
            # Check for section headers
            section_found = None
            for pattern, section_name in self.section_patterns:
                if re.search(pattern, line):
                    section_found = section_name
                    break
            
            if section_found and current_content:
                # Save previous section
                content = '\n'.join(current_content)
                chunks.append({
                    'file': filename,
                    'section': current_section,
                    'content': content,
                    'words': len(content.split()),
                    'chars': len(content)
                })
                current_content = []
                current_section = section_found
            
            current_content.append(line)
        
        # Save last section
        if current_content:
            content = '\n'.join(current_content)
            chunks.append({
                'file': filename,
                'section': current_section,
                'content': content,
                'words': len(content.split()),
                'chars': len(content)
            })
        
        # If no sections found, create size-based chunks
        if len(chunks) == 1 and chunks[0]['section'] == 'General':
            chunks = self.size_based_chunks(text, filename)
        
        self.stats['chunks'] += len(chunks)
        return chunks

    def size_based_chunks(self, text, filename, max_size=2000):
        """Create size-based chunks"""
        chunks = []
        words = text.split()
        chunk_words = []
        chunk_num = 1
        
        for word in words:
            chunk_words.append(word)
            if len(' '.join(chunk_words)) > max_size:
                content = ' '.join(chunk_words[:-1])
                chunks.append({
                    'file': filename,
                    'section': f'Part {chunk_num}',
                    'content': content,
                    'words': len(chunk_words) - 1,
                    'chars': len(content)
                })
                chunk_words = [word]
                chunk_num += 1
        
        if chunk_words:
            content = ' '.join(chunk_words)
            chunks.append({
                'file': filename,
                'section': f'Part {chunk_num}',
                'content': content,
                'words': len(chunk_words),
                'chars': len(content)
            })
        
        return chunks

    def preserve_structure(self, file_path):
        """Maintain original folder structure in output"""
        relative_path = file_path.relative_to(self.input_path)
        output_file_path = self.output_path / relative_path.parent
        output_file_path.mkdir(parents=True, exist_ok=True)
        return output_file_path

    def process_file(self, file_path):
        """Process single file"""
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                text = f.read()
            
            if not text.strip():
                return None
            
            # Clean text
            cleaned_text = self.clean_text(text)
            
            # Create output directory maintaining structure
            output_dir = self.preserve_structure(file_path)
            
            # Save cleaned text
            cleaned_file = output_dir / f"{file_path.stem}_cleaned.txt"
            with open(cleaned_file, 'w', encoding='utf-8') as f:
                f.write(cleaned_text)
            
            # Create chunks
            chunks = self.create_chunks(cleaned_text, file_path.name)
            
            # Save chunks in chunks subfolder
            chunks_dir = output_dir / "chunks"
            chunks_dir.mkdir(exist_ok=True)
            
            for i, chunk in enumerate(chunks):
                chunk_file = chunks_dir / f"{file_path.stem}_chunk_{i+1}_{chunk['section'].replace(' ', '_')}.txt"
                with open(chunk_file, 'w', encoding='utf-8') as f:
                    f.write(f"File: {chunk['file']}\nSection: {chunk['section']}\n")
                    f.write(f"Words: {chunk['words']} | Chars: {chunk['chars']}\n")
                    f.write("-" * 50 + "\n")
                    f.write(chunk['content'])
            
            self.stats['files'] += 1
            return {
                'file': file_path.name,
                'path': str(file_path.relative_to(self.input_path)),
                'original_size': len(text),
                'cleaned_size': len(cleaned_text),
                'chunks': len(chunks),
                'chunks_data': chunks
            }
            
        except Exception as e:
            print(f"Error processing {file_path}: {e}")
            return None

    def process_all(self):
        """Process all files maintaining folder structure"""
        print(f"Processing files from: {self.input_path}")
        print(f"Output to: {self.output_path}")
        
        txt_files = list(self.input_path.rglob("*.txt"))
        if not txt_files:
            print("No .txt files found!")
            return
        
        print(f"Found {len(txt_files)} files")
        
        for file_path in txt_files:
            print(f"Processing: {file_path.relative_to(self.input_path)}")
            result = self.process_file(file_path)
            if result:
                self.results.append(result)
        
        self.generate_reports()
        
        print(f"\nCompleted!")
        print(f"Files processed: {self.stats['files']}")
        print(f"Duplicates removed: {self.stats['duplicates']}")
        print(f"Chunks created: {self.stats['chunks']}")

    def generate_reports(self):
        """Generate summary reports"""
        if not self.results:
            return
        
        # Create reports directory
        reports_dir = self.output_path / "reports"
        reports_dir.mkdir(exist_ok=True)
        
        # Summary CSV
        summary_data = [{
            'file': r['file'],
            'path': r['path'],
            'original_size': r['original_size'],
            'cleaned_size': r['cleaned_size'],
            'reduction': f"{(1 - r['cleaned_size']/r['original_size'])*100:.1f}%",
            'chunks': r['chunks']
        } for r in self.results]
        
        pd.DataFrame(summary_data).to_csv(reports_dir / "summary.csv", index=False)
        
        # All chunks CSV
        all_chunks = []
        for r in self.results:
            for chunk in r['chunks_data']:
                all_chunks.append({
                    'file_path': r['path'],
                    'file_name': chunk['file'],
                    'section': chunk['section'],
                    'word_count': chunk['words'],
                    'char_count': chunk['chars']
                })
        
        pd.DataFrame(all_chunks).to_csv(reports_dir / "chunks.csv", index=False)
        
        # JSON report
        report = {
            'timestamp': datetime.now().isoformat(),
            'statistics': self.stats,
            'files': self.results
        }
        
        with open(reports_dir / "report.json", 'w') as f:
            json.dump(report, f, indent=2, default=str)
        
        print(f"Reports saved to: {reports_dir}")

    def search(self, term, case_sensitive=False):
        """Search across all processed content"""
        results = []
        for file_result in self.results:
            for chunk in file_result['chunks_data']:
                content = chunk['content'] if case_sensitive else chunk['content'].lower()
                search_term = term if case_sensitive else term.lower()
                
                if search_term in content:
                    # Get context around match
                    idx = content.find(search_term)
                    start = max(0, idx - 50)
                    end = min(len(content), idx + len(search_term) + 50)
                    context = content[start:end]
                    
                    results.append({
                        'file': file_result['path'],
                        'section': chunk['section'],
                        'context': context
                    })
        
        return results


# Simple usage
if __name__ == "__main__":
    input_folder = input("Enter input folder path: ").strip().strip('"')
    output_folder = input("Enter output folder path (optional): ").strip().strip('"')
    
    if not os.path.exists(input_folder):
        print(f"Path '{input_folder}' does not exist!")
        exit(1)
    
    processor = EfficientTextProcessor(input_folder, output_folder if output_folder else None)
    processor.process_all()
    
    # Interactive search
    while True:
        search_term = input("\nSearch term (or 'quit'): ").strip()
        if search_term.lower() in ['quit', 'q', '']:
            break
        
        results = processor.search(search_term)
        if results:
            print(f"Found {len(results)} matches:")
            for r in results[:3]:  # Show first 3
                print(f"  {r['file']} - {r['section']}")
                print(f"  ...{r['context'][:100]}...")
        else:
            print("No matches found")
# Out:
# Enter input folder path:  "C:\Users\siddhu\Desktop\text_files (201 to 300)"
# Enter output folder path (optional):
# Processing files from: C:\Users\siddhu\Desktop\text_files (201 to 300)
# Output to: C:\Users\siddhu\Desktop\text_files (201 to 300)_processed
# Found 777 files
# Processing: colleges\ABES Engineering College\ENGINEERING 2020.txt
# Processing: colleges\ABES Engineering College\ENGINEERING 2021.txt
# Processing: colleges\ABES Engineering College\ENGINEERING 2023.txt
# Processing: colleges\ABES Engineering College\ENGINEERING 2024.txt
# Processing: colleges\Army Institute of Technology\Engineering 2018.txt
# Processing: colleges\Army Institute of Technology\Engineering 2019.txt
# Processing: colleges\Army Institute of Technology\Engineering 2020.txt
# Processing: colleges\Army Institute of Technology\Engineering 2021.txt
# Processing: colleges\Army Institute of Technology\Engineering 2022.txt
# Processing: colleges\Army Institute of Technology\Engineering 2023.txt
# Processing: colleges\Bharati Vidyapeeths College of Engineering New delhi\Engineering 2023.txt
# Processing: colleges\Bharati Vidyapeeths College of Engineering New delhi\Engineering 2024.txt
# Processing: colleges\Bharati Vidyapeeths College of Engineering New delhi\overall 2018.txt
# Processing: colleges\Bharati Vidyapeeths College of Engineering New delhi\Overall 2019.txt
# Processing: colleges\Bharati Vidyapeeths College of Engineering New delhi\Overall 2020.txt
# Processing: colleges\Bharati Vidyapeeths College of Engineering New delhi\Overall 2021.txt
# Processing: colleges\Bharati Vidyapeeths College of Engineering New delhi\Overall 2022.txt
# Processing: colleges\Bharati Vidyapeeths College of Engineering New delhi\Overall 2023.txt
# Processing: colleges\Bharati Vidyapeeths College of Engineering New delhi\Overall 2024.txt
# Processing: colleges\Bharatiya Vidya Bhavan`s Sardar Patel Institute of Technology\Engineering 2019.txt
# Processing: colleges\Bharatiya Vidya Bhavan`s Sardar Patel Institute of Technology\Engineering 2020.txt
# Processing: colleges\Bharatiya Vidya Bhavan`s Sardar Patel Institute of Technology\Engineering 2021.txt
# Processing: colleges\Bharatiya Vidya Bhavan`s Sardar Patel Institute of Technology\Engineering 2022.txt
# Processing: colleges\Bharatiya Vidya Bhavan`s Sardar Patel Institute of Technology\Engineering 2023.txt
# Processing: colleges\BIT Sindri\Engineering 2019.txt
# Processing: colleges\BIT Sindri\Engineering 2020.txt
# Processing: colleges\BIT Sindri\Engineering 2021.txt
# Processing: colleges\BIT Sindri\Engineering 2022.txt
# Processing: colleges\BIT Sindri\Engineering 2023.txt
# Processing: colleges\BMS Institute of Technology & Management\Engineering 2019.txt
# Processing: colleges\BMS Institute of Technology & Management\Engineering 2021.txt
# Processing: colleges\BMS Institute of Technology & Management\SDG INSTITUTION 2025.txt
# Processing: colleges\College of Engineering & Technology, Bhubaneswar\Engineering 2018.txt
# Processing: colleges\College of Engineering & Technology, Bhubaneswar\Engineering 2019.txt
# Processing: colleges\College of Engineering & Technology, Bhubaneswar\Engineering 2020.txt
# Processing: colleges\College of Engineering & Technology, Bhubaneswar\Engineering 2024.txt
# Processing: colleges\College of Engineering & Technology, Bhubaneswar\Engineering 2025.txt
# Processing: colleges\Dhirubhai Ambani Institute of Information and Communication Technology\Engineering 2017.txt
# Processing: colleges\DIT University'\Engineering 2020.txt
# Processing: colleges\DIT University'\Engineering 2022.txt
# Processing: colleges\E.G.S. Pillay Engineering College\Engineering 2025.txt
# Processing: colleges\Galgotias College of Engineering & Technology\Engineering 2022.txt
# Processing: colleges\Galgotias College of Engineering & Technology\Engineering 2024.txt
# Processing: colleges\Gandhi Institute for Technological Advancement (GITA), Bhubaneswar\Engineering.txt
# Processing: colleges\Gandhi Institute for Technological Advancement (GITA), Bhubaneswar\Management.txt
# Processing: colleges\Gandhi Institute for Technological Advancement (GITA), Bhubaneswar\Overall.txt
# Processing: colleges\Gandhi Institute for Technological Advancement (GITA), Bhubaneswar\SDG.txt
# Processing: colleges\GIET University, Gunupur\Engineering 2019.txt
# Processing: colleges\GIET University, Gunupur\Engineering 2020.txt
# Processing: colleges\GIET University, Gunupur\Engineering 2021.txt
# Processing: colleges\GIET University, Gunupur\Engineering 2022.txt
# Processing: colleges\GIET University, Gunupur\Engineering 2023.txt
# Processing: colleges\GMR Institute of Technology\Engineering 2022.txt
# Processing: colleges\Government College of Technology\Engineering 2023.txt
# Processing: colleges\Government Engineering College, Thrissur\Engineering 2020.txt
# Processing: colleges\Government Engineering College, Thrissur\Engineering 2024.txt
# Processing: colleges\Government Engineering College, Thrissur\Engineering 2025.txt
# Processing: colleges\IES College of Technology, Bhopal\Engineering 2024.txt
# Processing: colleges\Indian Institute of Petroleum & Energy\Engineering 2024.txt
# Processing: colleges\Indian Institute of Petroleum & Energy\Engineering 2025.txt
# Processing: colleges\Institute of Infrastructure Technology Research and Management (IITRAM)\Engineering 2020.txt
# Processing: colleges\Institute of Infrastructure Technology Research and Management (IITRAM)\Engineering 2023.txt
# Processing: colleges\Institute of Infrastructure Technology Research and Management (IITRAM)\Engineering 2024.txt
# Processing: colleges\Integral University\Management 2021.txt
# Processing: colleges\Integral University\Overall 2023.txt
# Processing: colleges\International Institute of Information Technology Bhubaneswar\Engineering 2018.txt
# Processing: colleges\International Institute of Information Technology Bhubaneswar\Engineering 2020.txt
# Processing: colleges\International Institute of Information Technology Bhubaneswar\Engineering 2021.txt
# Processing: colleges\International Institute of Information Technology Bhubaneswar\Engineering 2022.txt
# Processing: colleges\International Institute of Information Technology Bhubaneswar\Engineering 2023.txt
# Processing: colleges\International Institute of Information Technology Bhubaneswar\Engineering 2024.txt
# Processing: colleges\International Institute of Information Technology Bhubaneswar\NIRF 2019 data.txt
# Processing: colleges\JIS College of Engineering\Engineering 2023.txt
# Processing: colleges\JIS College of Engineering\Engineering 2024.txt
# Processing: colleges\JIS College of Engineering\Engineering 2025.txt
# Processing: colleges\JSS Academy of Technical Education, Noida\Engineering 2020.txt
# Processing: colleges\JSS Academy of Technical Education, Noida\Engineering 2023.txt
# Processing: colleges\JSS Academy of Technical Education, Noida\Engineering 2024.txt
# Processing: colleges\JSS Academy of Technical Education, Noida\Engineering 2025.txt
# Processing: colleges\JSS Academy of Technical Education, Noida\NIRF-2018.txt
# Processing: colleges\JSS Academy of Technical Education, Noida\Overall 2019.txt
# Processing: colleges\JSS Science and Technology University\Engineering 2023.txt
# Processing: colleges\K. J. Somaiya College of Engineering\Engineering 2020.txt
# Processing: colleges\K. J. Somaiya College of Engineering\Engineering 2023.txt
# Processing: colleges\K.S. Rangasamy College of Technology\Engineering 2017.txt
# Processing: colleges\K.S. Rangasamy College of Technology\Engineering 2019.txt
# Processing: colleges\K.S. Rangasamy College of Technology\Engineering 2020.txt
# Processing: colleges\K.S. Rangasamy College of Technology\Engineering 2021.txt
# Processing: colleges\Kakatiya Institute of Technology & Science\Engineering 2021.txt
# Processing: colleges\Kakatiya Institute of Technology & Science\Overall 2017.txt
# Processing: colleges\Kakatiya Institute of Technology & Science\Overall 2018.txt
# Processing: colleges\Kakatiya Institute of Technology & Science\Overall 2020.txt
# Processing: colleges\Karpagam College of Engineering\Engineering 2020.txt
# Processing: colleges\KCG College of Technology\Enginnering 2020.txt
# Processing: colleges\Kurukshetra University\Overall 2018.txt
# Processing: colleges\Lakireddy Bali Reddy College of Engineering (LBRCE)\Engineering 2018.txt
# Processing: colleges\Lakireddy Bali Reddy College of Engineering (LBRCE)\Engineering 2019.txt
# Processing: colleges\Lakshmi Narain College of Technology\Engineering 2021.txt
# Processing: colleges\Lakshmi Narain College of Technology\Overall 2024.txt
# Processing: colleges\Madanapalle Institute of Technology & Science\Engineering 2020.txt
# Processing: colleges\Madanapalle Institute of Technology & Science\Engineering 2021.txt
# Processing: colleges\Madanapalle Institute of Technology & Science\Engineering 2022.txt
# Processing: colleges\Madanapalle Institute of Technology & Science\Engineering 2023.txt
# Processing: colleges\Maharaja Agrasen Institute of Technology\Overall 2017.txt
# Processing: colleges\Maharaja Sayajirao University of Baroda\Pharmacy  2022.txt
# Processing: colleges\Maharaja Surajmal Institute of Technology\Engineering  2018.txt
# Processing: colleges\Maharaja Surajmal Institute of Technology\Engineering  2019.txt
# Processing: colleges\Maharaja Surajmal Institute of Technology\Engineering  2020.txt
# Processing: colleges\Maharaja Surajmal Institute of Technology\Engineering  2021.txt
# Processing: colleges\Maharaja Surajmal Institute of Technology\Engineering  2022.txt
# Processing: colleges\Maharaja Surajmal Institute of Technology\Engineering  2023.txt
# Processing: colleges\Maharshi Dayanand University, Rohtak\Management 2020.txt
# Processing: colleges\Maharshi Karve Stree Shikshan Samstha's Cummins College of Engineering for Women\Engineering 2022.txt
# Processing: colleges\Maharshi Karve Stree Shikshan Samstha's Cummins College of Engineering for Women\Engineering 2023.txt
# Processing: colleges\Maharshi Karve Stree Shikshan Samstha's Cummins College of Engineering for Women\Engineering 2024.txt
# Processing: colleges\Maharshi Karve Stree Shikshan Samstha's Cummins College of Engineering for Women\Engineering 2025.txt
# Processing: colleges\Manav Rachna University\Engineering 2024.txt
# Processing: colleges\MLR Institute of Technology\Engineering 2024.txt
# Processing: colleges\Narasaraopeta Engineering College\Engineering 2022.txt
# Processing: colleges\Narula Institute of Technology\Engineering 2017.txt
# Processing: colleges\Narula Institute of Technology\Engineering 2018.txt
# Processing: colleges\Narula Institute of Technology\Engineering 2019.txt
# Processing: colleges\Narula Institute of Technology\Engineering 2020.txt
# Processing: colleges\Narula Institute of Technology\Engineering 2021.txt
# Processing: colleges\Narula Institute of Technology\Engineering 2022.txt
# Processing: colleges\Narula Institute of Technology\Engineering 2023.txt
# Processing: colleges\Narula Institute of Technology\Engineering 2024.txt
# Processing: colleges\Narula Institute of Technology\Engineering 2025.txt
# Processing: colleges\Padmashree Dr. D. Y. Patil Vidyapeeth, Mumbai\Dental 2024.txt
# Processing: colleges\Padmashree Dr. D. Y. Patil Vidyapeeth, Mumbai\Engineering 2024.txt
# Processing: colleges\Padmashree Dr. D. Y. Patil Vidyapeeth, Mumbai\Medical 2024.txt
# Processing: colleges\Padmashree Dr. D. Y. Patil Vidyapeeth, Mumbai\Overall 2022.txt
# Processing: colleges\Padmashree Dr. D. Y. Patil Vidyapeeth, Mumbai\Overall 2024.txt
# Processing: colleges\Panimalar Engineering College\Engineering 2025.txt
# Processing: colleges\Panimalar Engineering College\Management 2023.txt
# Processing: colleges\Panimalar Engineering College\Management 2025.txt
# Processing: colleges\Panimalar Engineering College\OVERALL 2024.txt
# Processing: colleges\Pondicherry Engineering College\Overall or Engineering.txt
# Processing: colleges\Prasad V Potluri Siddhartha Institue of Technology\Engineering 2018.txt
# Processing: colleges\Prasad V Potluri Siddhartha Institue of Technology\Overall 2017.txt
# Processing: colleges\PSNA College of Engineering and Technology, Dindigul\Engineering 2023.txt
# Processing: colleges\PSNA College of Engineering and Technology, Dindigul\Engineering 2024.txt
# Processing: colleges\QIS College of Engineering & Technology\Engineering 2019.txt
# Processing: colleges\QIS College of Engineering & Technology\Engineering 2020.txt
# Processing: colleges\QIS College of Engineering & Technology\Engineering 2021.txt
# Processing: colleges\QIS College of Engineering & Technology\Engineering 2022.txt
# Processing: colleges\R.M.D Engineering College\Engineering 2016.txt
# Processing: colleges\Rajeev Gandhi Memorial College of Engineering & Technology\Engineering 2022.txt
# Processing: colleges\Saveetha Engineering College\Engineering 2025.txt
# Processing: colleges\Saveetha Engineering College\Innovation 2025.txt
# Processing: colleges\Saveetha Engineering College\SDG 2025.txt
# Processing: colleges\Shri G. S. Institute of Technology & Science\Engineering 2021.txt
# Processing: colleges\Shri G. S. Institute of Technology & Science\Engineering 2022.txt
# Processing: colleges\Shri G. S. Institute of Technology & Science\Engineering 2023.txt
# Processing: colleges\Shri G. S. Institute of Technology & Science\Engineering 2024.txt
# Processing: colleges\Shri G. S. Institute of Technology & Science\Engineering 2025.txt
# Processing: colleges\Shri G. S. Institute of Technology & Science\Innovation 2024.txt
# Processing: colleges\Shri G. S. Institute of Technology & Science\Innovation 2025.txt
# Processing: colleges\Shri G. S. Institute of Technology & Science\Management 2021.txt
# Processing: colleges\Shri G. S. Institute of Technology & Science\Management 2022.txt
# Processing: colleges\Shri G. S. Institute of Technology & Science\Management 2023.txt
# Processing: colleges\Shri G. S. Institute of Technology & Science\Management 2024.txt
# Processing: colleges\Shri G. S. Institute of Technology & Science\Management 2025.txt
# Processing: colleges\Shri G. S. Institute of Technology & Science\Overall 2021.txt
# Processing: colleges\Shri G. S. Institute of Technology & Science\Overall 2022.txt
# Processing: colleges\Shri G. S. Institute of Technology & Science\Overall 2023.txt
# Processing: colleges\Shri G. S. Institute of Technology & Science\Overall 2024.txt
# Processing: colleges\Shri G. S. Institute of Technology & Science\Overall 2025.txt
# Processing: colleges\Shri G. S. Institute of Technology & Science\Pharmacy 2021.txt
# Processing: colleges\Shri G. S. Institute of Technology & Science\Pharmacy 2022.txt
# Processing: colleges\Shri G. S. Institute of Technology & Science\Pharmacy 2023.txt
# Processing: colleges\Shri G. S. Institute of Technology & Science\Pharmacy 2024.txt
# Processing: colleges\Shri G. S. Institute of Technology & Science\Pharmacy 2025.txt
# Processing: colleges\Shri Ramdeobaba College of Engineering and Management\2022.txt
# Processing: colleges\Shri Vile Parle Kelavani Mandal`s Dwarkadas J. Sanghvi College of Engineering\Engineering 2019.txt
# Processing: colleges\Shri Vile Parle Kelavani Mandal`s Dwarkadas J. Sanghvi College of Engineering\Engineering 2020.txt
# Processing: colleges\Shri Vile Parle Kelavani Mandal`s Dwarkadas J. Sanghvi College of Engineering\Engineering 2021.txt
# Processing: colleges\Shri Vile Parle Kelavani Mandal`s Dwarkadas J. Sanghvi College of Engineering\Engineering 2022.txt
# Processing: colleges\Shri Vile Parle Kelavani Mandal`s Dwarkadas J. Sanghvi College of Engineering\Engineering 2023.txt
# Processing: colleges\Shri Vile Parle Kelavani Mandal`s Dwarkadas J. Sanghvi College of Engineering\Engineering 2024.txt
# Processing: colleges\Shri Vile Parle Kelavani Mandal`s Dwarkadas J. Sanghvi College of Engineering\Engineering 2025.txt
# Processing: colleges\Shri Vile Parle Kelavani Mandal`s Dwarkadas J. Sanghvi College of Engineering\Innovation 2024.txt
# Processing: colleges\Shri Vile Parle Kelavani Mandal`s Dwarkadas J. Sanghvi College of Engineering\Innovation 2025.txt
# Processing: colleges\Shri Vile Parle Kelavani Mandal`s Dwarkadas J. Sanghvi College of Engineering\Overall 2020.txt
# Processing: colleges\Shri Vile Parle Kelavani Mandal`s Dwarkadas J. Sanghvi College of Engineering\Overall 2021.txt
# Processing: colleges\Sikkim Manipal Institute of Technology (SMIT)\Engineering 2018.txt
# Processing: colleges\Sikkim Manipal Institute of Technology (SMIT)\Engineering 2019.txt
# Processing: colleges\Sikkim Manipal Institute of Technology (SMIT)\Engineering 2020.txt
# Processing: colleges\Sikkim Manipal Institute of Technology (SMIT)\Engineering 2024.txt
# Processing: colleges\Sikkim Manipal Institute of Technology (SMIT)\Engineering 2025.txt
# Processing: colleges\Silicon Institute of Technology (SIT), Bhubaneswar\Engineering 2020.txt
# Processing: colleges\Silicon Institute of Technology (SIT), Bhubaneswar\Engineering 2022.txt
# Processing: colleges\Silicon Institute of Technology (SIT), Bhubaneswar\Engineering 2023.txt
# Processing: colleges\Silicon Institute of Technology (SIT), Bhubaneswar\Silicon-University Engneering 2025.txt
# Processing: colleges\Sree Vidyanikethan Engineering College\Engineering 2020.txt
# Processing: colleges\Sree Vidyanikethan Engineering College\Engineering 2023.txt
# Processing: colleges\Sreenidi Institute of Science &Technology\Engineering 2021.txt
# Processing: colleges\Sreenidi Institute of Science &Technology\Engineering 2022.txt
# Processing: colleges\Sreenidi Institute of Science &Technology\Engineering 2023.txt
# Processing: colleges\Sreenidi Institute of Science &Technology\Engineering 2024.txt
# Processing: colleges\Sreenidi Institute of Science &Technology\Engineering 2025.txt
# Processing: colleges\Sreenidi Institute of Science &Technology\Innovation 2025.txt
# Processing: colleges\Sreenidi Institute of Science &Technology\Management 2022.txt
# Processing: colleges\Sri Eshwar College of Engineering\Engineering 2021.txt
# Processing: colleges\Sri Eshwar College of Engineering\Engineering 2022.txt
# Processing: colleges\Sri Eshwar College of Engineering\Engineering 2023.txt
# Processing: colleges\Sri Manakula Vinayagar Engineering College\Engineering 2019.txt
# Processing: colleges\Sri Manakula Vinayagar Engineering College\Engineering 2020.txt
# Processing: colleges\Sri Manakula Vinayagar Engineering College\Engineering 2021.txt
# Processing: colleges\Sri Manakula Vinayagar Engineering College\Engineering 2022.txt
# Processing: colleges\Sri Manakula Vinayagar Engineering College\Engineering 2023.txt
# Processing: colleges\Sri Manakula Vinayagar Engineering College\Engineering 2024.txt
# Processing: colleges\Sri Manakula Vinayagar Engineering College\Engineering 2025.txt
# Processing: colleges\Sri Manakula Vinayagar Engineering College\innovation 2025.txt
# Processing: colleges\Sri Manakula Vinayagar Engineering College\Overall 2025.txt
# Processing: colleges\Sri Manakula Vinayagar Engineering College\SDG 2025.txt
# Processing: colleges\Sri Sai Ram Institute of Technology\Engineering 2017.txt
# Processing: colleges\Sri Sai Ram Institute of Technology\Engineering 2018.txt
# Processing: colleges\Sri Sai Ram Institute of Technology\Engineering 2019.txt
# Processing: colleges\Sri Sai Ram Institute of Technology\Engineering 2020.txt
# Processing: colleges\Sri Sai Ram Institute of Technology\Engineering 2021.txt
# Processing: colleges\Sri Sai Ram Institute of Technology\Engineering 2022.txt
# Processing: colleges\Sri Sai Ram Institute of Technology\Engineering 2023.txt
# Processing: colleges\Sri Venkateswara College of Engineering and Technology\Engineering 2023.txt
# Processing: colleges\Sri Venkateswara College of Engineering and Technology\Engineering 2024.txt
# Processing: colleges\Sri Venkateswara College of Engineering and Technology\Management 2022.txt
# Processing: colleges\Sri Venkateswara College of Engineering and Technology\Overall 2022.txt
# Processing: colleges\Sri Venkateswara College of Engineering and Technology\Overall 2023.txt
# Processing: colleges\Sri Venkateswara University\Overall 2024.txt
# Processing: colleges\Sri Venkateswara University\Overall 2025.txt
# Processing: colleges\St. Josephs College of Engineering\Engineering 2017.txt
# Processing: colleges\St. Josephs College of Engineering\Engineering 2018.txt
# Processing: colleges\St. Josephs College of Engineering\Engineering 2019.txt
# Processing: colleges\St. Josephs College of Engineering\Engineering 2020.txt
# Processing: colleges\St. Josephs College of Engineering\Engineering 2021.txt
# Processing: colleges\St. Josephs College of Engineering\Engineering 2022.txt
# Processing: colleges\St. Josephs College of Engineering\Engineering 2023.txt
# Processing: colleges\St. Josephs College of Engineering\Engineering 2024.txt
# Processing: colleges\The LNM Institute of Information Technology, Jaipur\Engineering 2016.txt
# Processing: colleges\University of Allahabad\Overall 2020.txt
# Processing: colleges\University of Allahabad\Overall 2021.txt
# Processing: colleges\University of Allahabad\Overall 2022.txt
# Processing: colleges\University of Allahabad\Overall 2023.txt
# Processing: colleges\Vasavi College of Engineering\Engineering 2017.txt
# Processing: colleges\Vasavi College of Engineering\Engineering 2018.txt
# Processing: colleges\Vasavi College of Engineering\Engineering 2019.txt
# Processing: colleges\Vasavi College of Engineering\Engineering 2020.txt
# Processing: colleges\Vasavi College of Engineering\Engineering 2021.txt
# Processing: colleges\Vasavi College of Engineering\Engineering 2022.txt
# Processing: colleges\Vasavi College of Engineering\Engineering 2023.txt
# Processing: colleges\Vasavi College of Engineering\Engineering 2024.txt
# Processing: colleges\Vasavi College of Engineering\Engineering 2025.txt
# Processing: colleges\Vasavi College of Engineering\Overall 2018.txt
# Processing: colleges\Vidya Jyothi Institute of Technology\Engineering 2018.txt
# Processing: colleges\Vidya Jyothi Institute of Technology\Engineering 2019.txt
# Processing: colleges\Vidya Jyothi Institute of Technology\Engineering 2020.txt
# Processing: colleges\Vidya Jyothi Institute of Technology\Engineering 2021.txt
# Processing: colleges\Vidya Jyothi Institute of Technology\Engineering 2022.txt
# Processing: colleges\Vidya Jyothi Institute of Technology\Engineering 2023.txt
# Processing: colleges\Vignan`s Institute of Information Technology\Engineering 2021.txt
# Processing: colleges\Vignan`s Institute of Information Technology\Engineering 2022.txt
# Processing: colleges\Vignan`s Institute of Information Technology\Engineering 2023.txt
# Processing: colleges\ABES Engineering College\2018\ENGINEERING.txt
# Processing: colleges\ABES Engineering College\2018\Higher Studies Students Details 2018.txt
# Processing: colleges\ABES Engineering College\2018\Sponsored Research Projects Detail 2018.txt
# Processing: colleges\ABES Engineering College\2019\ENGINEERING 2019 .txt
# Processing: colleges\ABES Engineering College\2019\Higher Studies Students Details 2019.txt
# Processing: colleges\ABES Engineering College\2019\Sponsored Research Project Details 2019.txt
# Processing: colleges\ABES Engineering College\2025\ENGINEERING .txt
# Processing: colleges\ABES Engineering College\2025\INNOVATION.txt
# Processing: colleges\Aditya Engineering College Surampalem\2017\Engineering.txt
# Processing: colleges\Aditya Engineering College Surampalem\2017\Overall.txt
# Processing: colleges\Aditya Engineering College Surampalem\2018\Engineering.txt
# Processing: colleges\Aditya Engineering College Surampalem\2018\Overall.txt
# Processing: colleges\Aditya Engineering College Surampalem\2019\Overall.txt
# Processing: colleges\Aditya Engineering College Surampalem\2021\Engineering.txt
# Processing: colleges\Aditya Engineering College Surampalem\2021\Overall.txt
# Processing: colleges\Aditya Engineering College Surampalem\2022\Engineering.txt
# Processing: colleges\Aditya Engineering College Surampalem\2022\Overall.txt
# Processing: colleges\Aditya Engineering College Surampalem\2024\Engineering.txt
# Processing: colleges\Aditya Engineering College Surampalem\2024\Overall.txt
# Processing: colleges\Amity University, Gwalior\2019\Management.txt
# Processing: colleges\Amity University, Gwalior\2019\Overall.txt
# Processing: colleges\Amity University, Gwalior\2020\Engineering.txt
# Processing: colleges\Amity University, Gwalior\2020\Management.txt
# Processing: colleges\Amity University, Gwalior\2020\Overall.txt
# Processing: colleges\Amity University, Gwalior\2021\Engineering.txt
# Processing: colleges\Amity University, Gwalior\2021\Law.txt
# Processing: colleges\Amity University, Gwalior\2021\Management.txt
# Processing: colleges\Amity University, Gwalior\2021\Overall.txt
# Processing: colleges\Amity University, Gwalior\2022\Engineering.txt
# Processing: colleges\Amity University, Gwalior\2022\Law.txt
# Processing: colleges\Amity University, Gwalior\2022\Overall.txt
# Processing: colleges\Amity University, Gwalior\2023\Engineering.txt
# Processing: colleges\Amity University, Gwalior\2023\Law.txt
# Processing: colleges\Amity University, Gwalior\2023\Overall.txt
# Processing: colleges\Amity University, Gwalior\2024\Engineering.txt
# Processing: colleges\Amity University, Gwalior\2024\Law.txt
# Processing: colleges\Amity University, Gwalior\2024\Management.txt
# Processing: colleges\Amity University, Gwalior\2024\Overall.txt
# Processing: colleges\Amity University, Gwalior\2025\Engineering.txt
# Processing: colleges\Amity University, Gwalior\2025\Law.txt
# Processing: colleges\Amity University, Gwalior\2025\Management.txt
# Processing: colleges\Amity University, Gwalior\2025\Overall.txt
# Processing: colleges\Army Institute of Technology\2024\Engineering.txt
# Processing: colleges\Army Institute of Technology\2024\Innovation.txt
# Processing: colleges\Army Institute of Technology\2025\Engineering.txt
# Processing: colleges\Army Institute of Technology\2025\Innovation.txt
# Processing: colleges\Bharatiya Vidya Bhavan`s Sardar Patel Institute of Technology\2024\Engineering 2024.txt
# Processing: colleges\Bharatiya Vidya Bhavan`s Sardar Patel Institute of Technology\2024\Innovation 2024.txt
# Processing: colleges\Bharatiya Vidya Bhavan`s Sardar Patel Institute of Technology\2024\Overall 2024.txt
# Processing: colleges\Bharatiya Vidya Bhavan`s Sardar Patel Institute of Technology\2025\Engineering 2025.txt
# Processing: colleges\Bharatiya Vidya Bhavan`s Sardar Patel Institute of Technology\2025\Faculty Information NIRF 2025.txt
# Processing: colleges\Bharatiya Vidya Bhavan`s Sardar Patel Institute of Technology\2025\Innovation 2025.txt
# Processing: colleges\Bharatiya Vidya Bhavan`s Sardar Patel Institute of Technology\2025\Overall 2025.txt
# Processing: colleges\BIT Sindri\2024\Engineering 2024.txt
# Processing: colleges\BIT Sindri\2024\Innovation 2024.txt
# Processing: colleges\BIT Sindri\2025\Engineering 2025.txt
# Processing: colleges\BIT Sindri\2025\Innovation 2025.txt
# Processing: colleges\BMS Institute of Technology & Management\2020\Engineering 2020.txt
# Processing: colleges\BMS Institute of Technology & Management\2020\Management 2020.txt
# Processing: colleges\BMS Institute of Technology & Management\2022\Engineering 2022.txt
# Processing: colleges\BMS Institute of Technology & Management\2022\Management  2022.txt
# Processing: colleges\BMS Institute of Technology & Management\2022\Overall 2022.txt
# Processing: colleges\BMS Institute of Technology & Management\2023\Engineering 2023.txt
# Processing: colleges\BMS Institute of Technology & Management\2023\Management 2023.txt
# Processing: colleges\BMS Institute of Technology & Management\2023\Overall.txt
# Processing: colleges\BMS Institute of Technology & Management\2024\Engineering 2024.txt
# Processing: colleges\BMS Institute of Technology & Management\2024\Innovation 2024.txt
# Processing: colleges\BMS Institute of Technology & Management\2024\Overall 2024.txt
# Processing: colleges\Centurion University of Technology and Management\2022\Engineering.txt
# Processing: colleges\Centurion University of Technology and Management\2022\Management.txt
# Processing: colleges\Centurion University of Technology and Management\2022\Overall.txt
# Processing: colleges\Centurion University of Technology and Management\2023\Engineering.txt
# Processing: colleges\Centurion University of Technology and Management\2023\Management.txt
# Processing: colleges\Centurion University of Technology and Management\2023\Overall.txt
# Processing: colleges\Centurion University of Technology and Management\2024\Agriculture.txt
# Processing: colleges\Centurion University of Technology and Management\2024\Engineering.txt
# Processing: colleges\Centurion University of Technology and Management\2024\Management.txt
# Processing: colleges\Centurion University of Technology and Management\2024\Overall.txt
# Processing: colleges\Centurion University of Technology and Management\2024\Pharmacy.txt
# Processing: colleges\Centurion University of Technology and Management\2025\Agriculture.txt
# Processing: colleges\Centurion University of Technology and Management\2025\Engineering.txt
# Processing: colleges\Centurion University of Technology and Management\2025\Innovation.txt
# Processing: colleges\Centurion University of Technology and Management\2025\Management.txt
# Processing: colleges\Centurion University of Technology and Management\2025\Overall.txt
# Processing: colleges\Centurion University of Technology and Management\2025\Pharmacy.txt
# Processing: colleges\Centurion University of Technology and Management\2025\SDG.txt
# Processing: colleges\Centurion University of Technology and Management\2025\Skill University.txt
# Processing: colleges\CMR Engineering College\2025\Engineering.txt
# Processing: colleges\CMR Engineering College\2025\Innovation.txt
# Processing: colleges\CMR Engineering College\2025\Overall.txt
# Processing: colleges\CMR Institute of Technology\2025\Engineering.txt
# Processing: colleges\CMR Institute of Technology\2025\Innovation.txt
# Processing: colleges\CMR Institute of Technology\2025\Overall.txt
# Processing: colleges\CMR Institute of Technology\2025\SDG.txt
# Processing: colleges\Dayananda Sagar College of Engineering\2020\Engineering.txt
# Processing: colleges\Dayananda Sagar College of Engineering\2020\Management.txt
# Processing: colleges\Dayananda Sagar College of Engineering\2020\Overall.txt
# Processing: colleges\Dayananda Sagar College of Engineering\2021\Engineering.txt
# Processing: colleges\Dayananda Sagar College of Engineering\2021\Managment.txt
# Processing: colleges\Dayananda Sagar College of Engineering\2021\Overall.txt
# Processing: colleges\Dayananda Sagar College of Engineering\2022\Engineering.txt
# Processing: colleges\Dayananda Sagar College of Engineering\2022\Management.txt
# Processing: colleges\Dayananda Sagar College of Engineering\2022\Overall.txt
# Processing: colleges\Dayananda Sagar College of Engineering\2023\Engineering.txt
# Processing: colleges\Dayananda Sagar College of Engineering\2023\Management.txt
# Processing: colleges\Dayananda Sagar College of Engineering\2023\Overall.txt
# Processing: colleges\Dayananda Sagar College of Engineering\2024\Engineering.txt
# Processing: colleges\Dayananda Sagar College of Engineering\2024\Innovation.txt
# Processing: colleges\Dayananda Sagar College of Engineering\2024\Management.txt
# Processing: colleges\Dayananda Sagar College of Engineering\2024\Overall.txt
# Processing: colleges\Dayananda Sagar College of Engineering\2025\Engineering.txt
# Processing: colleges\Dayananda Sagar College of Engineering\2025\Innovation.txt
# Processing: colleges\Dayananda Sagar College of Engineering\2025\Management.txt
# Processing: colleges\Dayananda Sagar College of Engineering\2025\Overall.txt
# Processing: colleges\Dayananda Sagar College of Engineering\2025\SDG.txt
# Processing: colleges\Dhirubhai Ambani Institute of Information and Communication Technology\2018\Engineering.txt
# Processing: colleges\Dhirubhai Ambani Institute of Information and Communication Technology\2018\Overall.txt
# Processing: colleges\Dhirubhai Ambani Institute of Information and Communication Technology\2019\Engineering.txt
# Processing: colleges\Dhirubhai Ambani Institute of Information and Communication Technology\2019\Overall.txt
# Processing: colleges\Dhirubhai Ambani Institute of Information and Communication Technology\2020\Engineering.txt
# Processing: colleges\Dhirubhai Ambani Institute of Information and Communication Technology\2020\Overall.txt
# Processing: colleges\Dhirubhai Ambani Institute of Information and Communication Technology\2021\Engineering.txt
# Processing: colleges\Dhirubhai Ambani Institute of Information and Communication Technology\2021\Overall.txt
# Processing: colleges\Dhirubhai Ambani Institute of Information and Communication Technology\2022\Engineering.txt
# Processing: colleges\Dhirubhai Ambani Institute of Information and Communication Technology\2022\Overall.txt
# Processing: colleges\Dhirubhai Ambani Institute of Information and Communication Technology\2023\Engineering.txt
# Processing: colleges\Dhirubhai Ambani Institute of Information and Communication Technology\2023\Overall.txt
# Processing: colleges\Dhirubhai Ambani Institute of Information and Communication Technology\2024\Engineering.txt
# Processing: colleges\Dhirubhai Ambani Institute of Information and Communication Technology\2024\Overall.txt
# Processing: colleges\Dhirubhai Ambani Institute of Information and Communication Technology\2025\Engineering.txt
# Processing: colleges\Dhirubhai Ambani Institute of Information and Communication Technology\2025\Overall.txt
# Processing: colleges\Dhirubhai Ambani Institute of Information and Communication Technology\2025\SDG.txt
# Processing: colleges\DIT University'\2021\Architecture 2021.txt
# Processing: colleges\DIT University'\2021\Engineering 2021.txt
# Processing: colleges\DIT University'\2024\Engineering 2024.txt
# Processing: colleges\DIT University'\2024\Pharmacy.txt
# Processing: colleges\DIT University'\2025\Engineering 2025.txt
# Processing: colleges\DIT University'\2025\Pharmacy 2025.txt
# Processing: colleges\Galgotias College of Engineering & Technology\2025\Engineering 2025.txt
# Processing: colleges\Galgotias College of Engineering & Technology\2025\Overall 2025.txt
# Processing: colleges\GIET University, Gunupur\2024\Agriculture And Allied Sectors.txt
# Processing: colleges\GIET University, Gunupur\2024\Engineering.txt
# Processing: colleges\GIET University, Gunupur\2024\Management.txt
# Processing: colleges\GIET University, Gunupur\2025\Agriculture And Allied Sectors.txt
# Processing: colleges\GIET University, Gunupur\2025\Engineering.txt
# Processing: colleges\GIET University, Gunupur\2025\Management.txt
# Processing: colleges\GIET University, Gunupur\2025\Overall.txt
# Processing: colleges\Government Engineering College, Thrissur\2021\Architecture 2021.txt
# Processing: colleges\Government Engineering College, Thrissur\2021\Engineering 2021.txt
# Processing: colleges\Government Engineering College, Thrissur\2022\Architecture 2022.txt
# Processing: colleges\Government Engineering College, Thrissur\2022\Engineering 2022.txt
# Processing: colleges\Government Engineering College, Thrissur\2023\Architecture 2023.txt
# Processing: colleges\Government Engineering College, Thrissur\2023\Engineering 2023.txt
# Processing: colleges\Haldia Institute of Technology\2022\Engineering 2022.txt
# Processing: colleges\Haldia Institute of Technology\2022\Overall 2022.txt
# Processing: colleges\Haldia Institute of Technology\2023\Engineering 2023.txt
# Processing: colleges\Haldia Institute of Technology\2023\Overall 2023.txt
# Processing: colleges\Haldia Institute of Technology\2024\Engineering 2024.txt
# Processing: colleges\Haldia Institute of Technology\2024\Innovation 2024.txt
# Processing: colleges\Haldia Institute of Technology\2025\Engineering 2025.txt
# Processing: colleges\Haldia Institute of Technology\2025\Innovation 2025.txt
# Processing: colleges\Institute of Infrastructure Technology Research and Management (IITRAM)\2025\Engineering 2025.txt
# Processing: colleges\Institute of Infrastructure Technology Research and Management (IITRAM)\2025\Overall 2025.txt
# Processing: colleges\Integral University\2025\Agriculture And Allied Sectors 2025.txt
# Processing: colleges\Integral University\2025\Engineering 2025.txt
# Processing: colleges\Integral University\2025\Management 2025.txt
# Processing: colleges\Integral University\2025\Overall 2025.txt
# Processing: colleges\Integral University\2025\Pharmacy 2025.txt
# Processing: colleges\Integral University\2025\SDG 2025.txt
# Processing: colleges\International Institute of Information Technology Bhubaneswar\2025\Engineering 2025.txt
# Processing: colleges\Jamia Hamdard\2024\Engineering 2024.txt
# Processing: colleges\Jamia Hamdard\2024\Innovation 2024.txt
# Processing: colleges\Jamia Hamdard\2024\Management 2024.txt
# Processing: colleges\Jamia Hamdard\2024\Medical 2024.txt
# Processing: colleges\Jamia Hamdard\2024\Overall 2024.txt
# Processing: colleges\Jamia Hamdard\2024\Pharmacy 2024.txt
# Processing: colleges\Jamia Hamdard\2025\Engineering 2025.txt
# Processing: colleges\Jamia Hamdard\2025\Innovation 2025.txt
# Processing: colleges\Jamia Hamdard\2025\Management 2025.txt
# Processing: colleges\Jamia Hamdard\2025\Medical 2025.txt
# Processing: colleges\Jamia Hamdard\2025\Overall 2025.txt
# Processing: colleges\Jamia Hamdard\2025\Pharmacy 2025.txt
# Processing: colleges\Jamia Hamdard\2025\SDG 2025.txt
# Processing: colleges\Jaypee University of Information Technology\2017\Engineering 2017.txt
# Processing: colleges\Jaypee University of Information Technology\2017\Overall 2017.txt
# Processing: colleges\Jaypee University of Information Technology\2018\Engineering 2018.txt
# Processing: colleges\Jaypee University of Information Technology\2018\Overall 2018.txt
# Processing: colleges\Jaypee University of Information Technology\2019\Engineering 2019.txt
# Processing: colleges\Jaypee University of Information Technology\2019\Overall 2019.txt
# Processing: colleges\Jaypee University of Information Technology\2020\Engineering 2020.txt
# Processing: colleges\Jaypee University of Information Technology\2020\Overall 2020.txt
# Processing: colleges\Jaypee University of Information Technology\2021\Engineering 2021.txt
# Processing: colleges\Jaypee University of Information Technology\2021\Overall 2021.txt
# Processing: colleges\Jaypee University of Information Technology\2022\Engineering 2022.txt
# Processing: colleges\Jaypee University of Information Technology\2022\Overall 2022.txt
# Processing: colleges\Jaypee University of Information Technology\2023\Engineering 2023.txt
# Processing: colleges\Jaypee University of Information Technology\2023\Overall 2023.txt
# Processing: colleges\Jaypee University of Information Technology\2024\Engineering 2024.txt
# Processing: colleges\Jaypee University of Information Technology\2024\Innovation 2024.txt
# Processing: colleges\Jaypee University of Information Technology\2024\Overall 2024.txt
# Processing: colleges\K. Ramakrishnan College of Engineering Samayapuram\2025\Engineering 2025.txt
# Processing: colleges\K. Ramakrishnan College of Engineering Samayapuram\2025\Overall 2025.txt
# Processing: colleges\K. Ramakrishnan College of Technology Trichurapalli\2024\Engineering 2024.txt
# Processing: colleges\K. Ramakrishnan College of Technology Trichurapalli\2024\Innovation 2024.txt
# Processing: colleges\K. Ramakrishnan College of Technology Trichurapalli\2024\Overall 2024.txt
# Processing: colleges\K.S. Rangasamy College of Technology\2022\Engineering 2022.txt
# Processing: colleges\K.S. Rangasamy College of Technology\2022\Overall 2022.txt
# Processing: colleges\K.S. Rangasamy College of Technology\2023\Engineering  2023.txt
# Processing: colleges\K.S. Rangasamy College of Technology\2023\Innovation 2023.txt
# Processing: colleges\K.S. Rangasamy College of Technology\2023\Overall 2023.txt
# Processing: colleges\K.S. Rangasamy College of Technology\2024\Engineering  2024.txt
# Processing: colleges\K.S. Rangasamy College of Technology\2024\Innovation 2024.txt
# Processing: colleges\K.S. Rangasamy College of Technology\2024\Overall 2024.txt
# Processing: colleges\K.S. Rangasamy College of Technology\2025\Engineering  2025.txt
# Processing: colleges\K.S. Rangasamy College of Technology\2025\Innovation 2025.txt
# Processing: colleges\K.S. Rangasamy College of Technology\2025\Overall 2025.txt
# Processing: colleges\K.S. Rangasamy College of Technology\2025\SDG 2025.txt
# Processing: colleges\Kakatiya Institute of Technology & Science\2022\Engineering 2022.txt
# Processing: colleges\Kakatiya Institute of Technology & Science\2022\Overall 2022.txt
# Processing: colleges\Kakatiya Institute of Technology & Science\2023\Engineering 2023.txt
# Processing: colleges\Kakatiya Institute of Technology & Science\2023\Overall 2023.txt
# Processing: colleges\Kakatiya Institute of Technology & Science\2024\Engineering 2024.txt
# Processing: colleges\Kakatiya Institute of Technology & Science\2024\Innovation 2024.txt
# Processing: colleges\Kakatiya Institute of Technology & Science\2024\Overall 2024.txt
# Processing: colleges\Kakatiya Institute of Technology & Science\2025\Engineering 2025.txt
# Processing: colleges\Kakatiya Institute of Technology & Science\2025\Innovation 2025.txt
# Processing: colleges\Kakatiya Institute of Technology & Science\2025\Overall 2025.txt
# Processing: colleges\Kalaignar Karunanidhi Institute of Technology\2025\Engineering 2025.txt
# Processing: colleges\Kalaignar Karunanidhi Institute of Technology\2025\Innovation 2025.txt
# Processing: colleges\Kalaignar Karunanidhi Institute of Technology\2025\Overall 2025.txt
# Processing: colleges\Kalaignar Karunanidhi Institute of Technology\2025\SDG 2025.txt
# Processing: colleges\KCG College of Technology\2022\Engineering 2022.txt
# Processing: colleges\KCG College of Technology\2022\Overall 2022.txt
# Processing: colleges\KCG College of Technology\2023\Engineering 2023.txt
# Processing: colleges\KCG College of Technology\2023\Overall 2022.txt
# Processing: colleges\KCG College of Technology\2024\Engineering 2024.txt
# Processing: colleges\KCG College of Technology\2024\Innovation 2024.txt
# Processing: colleges\KCG College of Technology\2024\Overall 2024.txt
# Processing: colleges\KCG College of Technology\2025\Engineering 2025.txt
# Processing: colleges\KCG College of Technology\2025\Innovation 2025.txt
# Processing: colleges\KCG College of Technology\2025\Overall 2025.txt
# Processing: colleges\KCG College of Technology\2025\SDG.txt
# Processing: colleges\Kurukshetra University\2019\Engineering 2019.txt
# Processing: colleges\Kurukshetra University\2019\Management 2019.txt
# Processing: colleges\Kurukshetra University\2019\Overall 2019.txt
# Processing: colleges\Kurukshetra University\2019\Pharmacy 2019.txt
# Processing: colleges\Kurukshetra University\2020\Engineering 2020.txt
# Processing: colleges\Kurukshetra University\2020\Management 2020.txt
# Processing: colleges\Kurukshetra University\2020\Overall 2020.txt
# Processing: colleges\Kurukshetra University\2020\Pharmacy 2020.txt
# Processing: colleges\Kurukshetra University\2021\Engineering 2021.txt
# Processing: colleges\Kurukshetra University\2021\Management 2021.txt
# Processing: colleges\Kurukshetra University\2021\Overall 2021.txt
# Processing: colleges\Kurukshetra University\2021\Pharmacy 2021.txt
# Processing: colleges\Kurukshetra University\2022\Engineering 2022.txt
# Processing: colleges\Kurukshetra University\2022\Management 2022.txt
# Processing: colleges\Kurukshetra University\2022\Overall 2022.txt
# Processing: colleges\Kurukshetra University\2022\Pharmacy 2022.txt
# Processing: colleges\Kurukshetra University\2023\Engineering 2023.txt
# Processing: colleges\Kurukshetra University\2023\Management 2023.txt
# Processing: colleges\Kurukshetra University\2023\Overall 2023.txt
# Processing: colleges\Kurukshetra University\2023\Pharmacy 2023.txt
# Processing: colleges\Kurukshetra University\2024\Engineering 2024.txt
# Processing: colleges\Kurukshetra University\2024\Innovation 2024.txt
# Processing: colleges\Kurukshetra University\2024\Management 2024.txt
# Processing: colleges\Kurukshetra University\2024\Overall 2024.txt
# Processing: colleges\Kurukshetra University\2024\Pharmacy 2024.txt
# Processing: colleges\Kurukshetra University\2025\Engineering 2025.txt
# Processing: colleges\Kurukshetra University\2025\Management 2025.txt
# Processing: colleges\Kurukshetra University\2025\Overall 2025.txt
# Processing: colleges\Kurukshetra University\2025\Pharamacy 2025.txt
# Processing: colleges\Kurukshetra University\2025\SDG 2025.txt
# Processing: colleges\Lakireddy Bali Reddy College of Engineering (LBRCE)\2020\Engineering 2020.txt
# Processing: colleges\Lakireddy Bali Reddy College of Engineering (LBRCE)\2020\Management 2020.txt
# Processing: colleges\Lakireddy Bali Reddy College of Engineering (LBRCE)\2021\Engineering 2021.txt
# Processing: colleges\Lakireddy Bali Reddy College of Engineering (LBRCE)\2021\Management 2021.txt
# Processing: colleges\Lakireddy Bali Reddy College of Engineering (LBRCE)\2021\Overall 2021.txt
# Processing: colleges\Lakireddy Bali Reddy College of Engineering (LBRCE)\2022\Engineering 2022.txt
# Processing: colleges\Lakireddy Bali Reddy College of Engineering (LBRCE)\2022\Management 2022.txt
# Processing: colleges\Lakireddy Bali Reddy College of Engineering (LBRCE)\2022\Overall 2022.txt
# Processing: colleges\Lakireddy Bali Reddy College of Engineering (LBRCE)\2023\Engineering 2023.txt
# Processing: colleges\Lakireddy Bali Reddy College of Engineering (LBRCE)\2023\Innovation 2023.txt
# Processing: colleges\Lakireddy Bali Reddy College of Engineering (LBRCE)\2023\Overall 2023.txt
# Processing: colleges\Lakireddy Bali Reddy College of Engineering (LBRCE)\2024\Engineering 2024.txt
# Processing: colleges\Lakireddy Bali Reddy College of Engineering (LBRCE)\2024\Innovation 2024.txt
# Processing: colleges\Lakireddy Bali Reddy College of Engineering (LBRCE)\2024\Overall 2024.txt
# Processing: colleges\Lakireddy Bali Reddy College of Engineering (LBRCE)\2025\Engineering 2025.txt
# Processing: colleges\Lakireddy Bali Reddy College of Engineering (LBRCE)\2025\Innovation 2025.txt
# Processing: colleges\Lakireddy Bali Reddy College of Engineering (LBRCE)\2025\Overall 2025.txt
# Processing: colleges\Lakireddy Bali Reddy College of Engineering (LBRCE)\2025\SDG 2025.txt
# Processing: colleges\Madanapalle Institute of Technology & Science\2017\Engineering 2017.txt
# Processing: colleges\Madanapalle Institute of Technology & Science\2017\Management 2017.txt
# Processing: colleges\Madanapalle Institute of Technology & Science\2018\Engineering 2018.txt
# Processing: colleges\Madanapalle Institute of Technology & Science\2018\Management 2018.txt
# Processing: colleges\Madanapalle Institute of Technology & Science\2019\Engineering 2019.txt
# Processing: colleges\Madanapalle Institute of Technology & Science\2019\Management 2019.txt
# Processing: colleges\Madanapalle Institute of Technology & Science\2019\Overall 2019.txt
# Processing: colleges\Madanapalle Institute of Technology & Science\2024\Engineering 2024.txt
# Processing: colleges\Madanapalle Institute of Technology & Science\2024\Innovation 2024.txt
# Processing: colleges\Madanapalle Institute of Technology & Science\2024\Overall 2024.txt
# Processing: colleges\Madanapalle Institute of Technology & Science\2025\Engineering 2025.txt
# Processing: colleges\Madanapalle Institute of Technology & Science\2025\Innovation 2025.txt
# Processing: colleges\Madanapalle Institute of Technology & Science\2025\Overall 2025.txt
# Processing: colleges\Madanapalle Institute of Technology & Science\2025\SDG 2025.txt
# Processing: colleges\Maharaja Agrasen Institute of Technology\2018\Engineering 2018.txt
# Processing: colleges\Maharaja Agrasen Institute of Technology\2018\Management 2018.txt
# Processing: colleges\Maharaja Agrasen Institute of Technology\2018\Overall 2018.txt
# Processing: colleges\Maharaja Agrasen Institute of Technology\2019\Engineering 2019.txt
# Processing: colleges\Maharaja Agrasen Institute of Technology\2019\Management 2019.txt
# Processing: colleges\Maharaja Agrasen Institute of Technology\2019\Overall 2019.txt
# Processing: colleges\Maharaja Agrasen Institute of Technology\2020\Engineering 2020.txt
# Processing: colleges\Maharaja Agrasen Institute of Technology\2020\Management 2020.txt
# Processing: colleges\Maharaja Agrasen Institute of Technology\2020\Overall 2020.txt
# Processing: colleges\Maharaja Agrasen Institute of Technology\2022\Engineering 2022.txt
# Processing: colleges\Maharaja Agrasen Institute of Technology\2022\Management 2022.txt
# Processing: colleges\Maharaja Agrasen Institute of Technology\2022\Overall 2022.txt
# ...
# Processing: colleges\Maharaja Agrasen Institute of Technology\2025\Innovation 2025.txt
# Processing: colleges\Maharaja Agrasen Institute of Technology\2025\Management 2025.txt
# Processing: colleges\Maharaja Agrasen Institute of Technology\2025\Overall 2025.txt
# Processing: colleges\Maharaja Surajmal Institute of Technology\2025\Engineering  2025.txt
# Processing: colleges\Maharaja Surajmal Institute of Technology\2025\Innovation 2025.txt
# Processing: colleges\Maharaja Surajmal Institute of Technology\2025\Overall 2025.txt
# Processing: colleges\Manav Rachna University\2025\Engineering 2025.txt
# Processing: colleges\Manav Rachna University\2025\Innovation 2025.txt
# Processing: colleges\Manav Rachna University\2025\Overall 2025.txt
# Processing: colleges\Manav Rachna University\2025\SDG 2025.txt
# Processing: colleges\MLR Institute of Technology\2025\Engineering 2025.txt
# Processing: colleges\MLR Institute of Technology\2025\Innovation 2025.txt
# Processing: colleges\MLR Institute of Technology\2025\SDG 2025.txt
# Processing: colleges\P E S College of Engineering, Mandya\2019\Engineering 2019.txt
# Processing: colleges\P E S College of Engineering, Mandya\2019\Management 2019.txt
# Processing: colleges\P E S College of Engineering, Mandya\2019\Overall 2019.txt
# Processing: colleges\P E S College of Engineering, Mandya\2020\Engineering 2020.txt
# Processing: colleges\P E S College of Engineering, Mandya\2020\Management 2020.txt
# Processing: colleges\P E S College of Engineering, Mandya\2020\Overall 2020.txt
# Processing: colleges\P E S College of Engineering, Mandya\2021\Engineering 2021.txt
# Processing: colleges\P E S College of Engineering, Mandya\2021\Management 2021.txt
# Processing: colleges\P E S College of Engineering, Mandya\2022\Engineering 2022.txt
# Processing: colleges\P E S College of Engineering, Mandya\2022\Management 2022.txt
# Processing: colleges\P E S College of Engineering, Mandya\2022\Overall 2022.txt
# Processing: colleges\P E S College of Engineering, Mandya\2023\Engineering 2023.txt
# Processing: colleges\P E S College of Engineering, Mandya\2023\Innovation 2023.txt
# Processing: colleges\P E S College of Engineering, Mandya\2023\Management 2023.txt
# Processing: colleges\P E S College of Engineering, Mandya\2024\Engineering 2024.txt
# Processing: colleges\P E S College of Engineering, Mandya\2024\Innovation 2024.txt
# Processing: colleges\P E S College of Engineering, Mandya\2024\Overall2024.txt
# Processing: colleges\P E S College of Engineering, Mandya\2025\Engineering 2025.txt
# Processing: colleges\P E S College of Engineering, Mandya\2025\Innovation 2025.txt
# Processing: colleges\P E S College of Engineering, Mandya\2025\Overall 2025.txt
# Processing: colleges\Prasad V Potluri Siddhartha Institue of Technology\2019\Engineering 2019.txt
# Processing: colleges\Prasad V Potluri Siddhartha Institue of Technology\2019\Overall 2019.txt
# Processing: colleges\Prasad V Potluri Siddhartha Institue of Technology\2020\Engineering 2020.txt
# Processing: colleges\Prasad V Potluri Siddhartha Institue of Technology\2020\Overall 2020.txt
# Processing: colleges\Prasad V Potluri Siddhartha Institue of Technology\2021\Engineering 2018.txt
# Processing: colleges\Prasad V Potluri Siddhartha Institue of Technology\2021\Engineering 2021.txt
# Processing: colleges\Prasad V Potluri Siddhartha Institue of Technology\2021\Overall 2021.txt
# Processing: colleges\Prasad V Potluri Siddhartha Institue of Technology\2022\Engineering 2022.txt
# Processing: colleges\Prasad V Potluri Siddhartha Institue of Technology\2022\Overall 2022.txt
# Processing: colleges\Prasad V Potluri Siddhartha Institue of Technology\2023\Engineering 2023.txt
# Processing: colleges\Prasad V Potluri Siddhartha Institue of Technology\2023\Overall 2023.txt
# Processing: colleges\Prasad V Potluri Siddhartha Institue of Technology\2024\Engineering 2024.txt
# Processing: colleges\Prasad V Potluri Siddhartha Institue of Technology\2024\Innovation 2024.txt
# Processing: colleges\Prasad V Potluri Siddhartha Institue of Technology\2024\Overall 2024.txt
# Processing: colleges\Prasad V Potluri Siddhartha Institue of Technology\2025\Engineering 2025.txt
# Processing: colleges\Prasad V Potluri Siddhartha Institue of Technology\2025\Innovation 2025.txt
# Processing: colleges\Prasad V Potluri Siddhartha Institue of Technology\2025\Overall 2025.txt
# Processing: colleges\PSNA College of Engineering and Technology, Dindigul\2025\Engineering 2025.txt
# Processing: colleges\PSNA College of Engineering and Technology, Dindigul\2025\Innovation 2025.txt
# Processing: colleges\R. M. K. College of Engineering and Technology\2024\Engineering 2024.txt
# Processing: colleges\R. M. K. College of Engineering and Technology\2024\Innovation 2024.txt
# Processing: colleges\R. M. K. College of Engineering and Technology\2024\Overall 2024.txt
# Processing: colleges\R. M. K. College of Engineering and Technology\2025\Engineering 2025.txt
# Processing: colleges\R. M. K. College of Engineering and Technology\2025\Innovation 2025.txt
# Processing: colleges\R. M. K. College of Engineering and Technology\2025\Overall 2025.txt
# Processing: colleges\R. M. K. College of Engineering and Technology\2025\SDG 2025.txt
# Processing: colleges\R.M.D Engineering College\2018\Engineering 2018.txt
# Processing: colleges\R.M.D Engineering College\2018\Overall 2018.txt
# Processing: colleges\R.M.D Engineering College\2019\Engineering 2019.txt
# Processing: colleges\R.M.D Engineering College\2019\Overall 2019.txt
# Processing: colleges\R.M.D Engineering College\2020\Engineering 2020.txt
# Processing: colleges\R.M.D Engineering College\2020\Overall 2020.txt
# Processing: colleges\R.M.D Engineering College\2021\Engineering 2021.txt
# Processing: colleges\R.M.D Engineering College\2021\Overall 2021.txt
# Processing: colleges\R.M.D Engineering College\2022\Engineering 2022.txt
# Processing: colleges\R.M.D Engineering College\2022\Overall 2022.txt
# Processing: colleges\R.M.D Engineering College\2023\Engineering 2023.txt
# Processing: colleges\R.M.D Engineering College\2023\Overall 2023.txt
# Processing: colleges\R.M.D Engineering College\2024\Engineering 2024.txt
# Processing: colleges\R.M.D Engineering College\2024\Overall 2024.txt
# Processing: colleges\R.M.D Engineering College\2025\Engineering 2025.txt
# Processing: colleges\R.M.D Engineering College\2025\Innovation 2025.txt
# Processing: colleges\R.M.D Engineering College\2025\Overall 2025.txt
# Processing: colleges\R.M.D Engineering College\2025\SDG  2025.txt
# Processing: colleges\R.V. R. & J. C. College of Engineering\2021\Engineering 2021.txt
# Processing: colleges\R.V. R. & J. C. College of Engineering\2021\Management 2021.txt
# Processing: colleges\R.V. R. & J. C. College of Engineering\2021\Overall 2021.txt
# Processing: colleges\R.V. R. & J. C. College of Engineering\2025\Engineering 2025.txt
# Processing: colleges\R.V. R. & J. C. College of Engineering\2025\Innovation 2025.txt
# Processing: colleges\R.V. R. & J. C. College of Engineering\2025\Management 2025.txt
# Processing: colleges\R.V. R. & J. C. College of Engineering\2025\Overall 2025.txt
# Processing: colleges\R.V. R. & J. C. College of Engineering\2025\SDG 2025.txt
# Processing: colleges\Rabindranath Tagore University\2023\Engineering 2023.txt
# Processing: colleges\Rabindranath Tagore University\2023\NIRF Overall.txt
# Processing: colleges\Rabindranath Tagore University\2024\Engineering 2024.txt
# Processing: colleges\Rabindranath Tagore University\2024\Innovation 2024.txt
# Processing: colleges\Rabindranath Tagore University\2024\Overall 2024.txt
# Processing: colleges\Rabindranath Tagore University\2025\Engineering 2025.txt
# Processing: colleges\Rabindranath Tagore University\2025\Innovation 2025.txt
# Processing: colleges\Rabindranath Tagore University\2025\Overall 2025.txt
# Processing: colleges\Rabindranath Tagore University\2025\SDG 2025.txt
# Processing: colleges\Rajeev Gandhi Memorial College of Engineering & Technology\2023\Engineering 2023.txt
# Processing: colleges\Rajeev Gandhi Memorial College of Engineering & Technology\2023\Overall 2023.txt
# Processing: colleges\Reva University\2023\Architecture _ Planning 2023.txt
# Processing: colleges\Reva University\2023\Engineering 2023.txt
# Processing: colleges\Reva University\2023\Law 2023.txt
# Processing: colleges\Reva University\2023\Management 2023.txt
# Processing: colleges\Reva University\2023\Overall 2023.txt
# Processing: colleges\Reva University\2024\Architecture _ Planning 2024.txt
# Processing: colleges\Reva University\2024\Engineering 2024.txt
# Processing: colleges\Reva University\2024\Innovation 2024.txt
# Processing: colleges\Reva University\2024\Law 2024.txt
# Processing: colleges\Reva University\2024\Management 2024.txt
# Processing: colleges\Reva University\2024\Overall 2024.txt
# Processing: colleges\Reva University\2025\Architecture _ Planning 2025.txt
# Processing: colleges\Reva University\2025\Engineering 2025.txt
# Processing: colleges\Reva University\2025\Innovation 2025.txt
# Processing: colleges\Reva University\2025\Law 2025.txt
# Processing: colleges\Reva University\2025\Management 2025.txt
# Processing: colleges\Reva University\2025\Overall 2025.txt
# Processing: colleges\Reva University\2025\SDG 2025.txt
# Processing: colleges\Shri Ramdeobaba College of Engineering and Management\2024\Engieering 2024.txt
# Processing: colleges\Shri Ramdeobaba College of Engineering and Management\2024\Innovation 2024.txt
# Processing: colleges\Shri Ramdeobaba College of Engineering and Management\2024\Management 2024.txt
# Processing: colleges\Shri Ramdeobaba College of Engineering and Management\2024\Overall 2024.txt
# Processing: colleges\Sikkim Manipal Institute of Technology (SMIT)\2021\Engineering 2021.txt
# Processing: colleges\Sikkim Manipal Institute of Technology (SMIT)\2021\Overall 2021.txt
# Processing: colleges\Sikkim Manipal Institute of Technology (SMIT)\2022\Engineering 2022.txt
# Processing: colleges\Sikkim Manipal Institute of Technology (SMIT)\2022\Management 2022.txt
# Processing: colleges\Sikkim Manipal Institute of Technology (SMIT)\2022\Overall 2022.txt
# Processing: colleges\Sikkim Manipal Institute of Technology (SMIT)\2023\Engineering 2023.txt
# Processing: colleges\Sikkim Manipal Institute of Technology (SMIT)\2023\Overall 2023.txt
# Processing: colleges\Silicon Institute of Technology (SIT), Bhubaneswar\2024\Engineering 2024.txt
# Processing: colleges\Silicon Institute of Technology (SIT), Bhubaneswar\2024\Innovation 2024.txt
# Processing: colleges\SNS College of Technology\2025\Engineering 2025.txt
# Processing: colleges\SNS College of Technology\2025\Innovation 2025.txt
# Processing: colleges\SNS College of Technology\2025\Overall 2025.txt
# Processing: colleges\SNS College of Technology\2025\SDG 2025.txt
# Processing: colleges\Sree Vidyanikethan Engineering College\2024\Engineering 2024.txt
# Processing: colleges\Sree Vidyanikethan Engineering College\2024\Innovation 2024.txt
# Processing: colleges\Sree Vidyanikethan Engineering College\2025\Engineering 2025.txt
# Processing: colleges\Sree Vidyanikethan Engineering College\2025\Innovation 2025.txt
# Processing: colleges\Sree Vidyanikethan Engineering College\2025\SDG 2025.txt
# Processing: colleges\Sri Eshwar College of Engineering\2024\Engineering 2024.txt
# Processing: colleges\Sri Eshwar College of Engineering\2024\Innovation 2024.txt
# Processing: colleges\Sri Eshwar College of Engineering\2024\Overall 2024.txt
# Processing: colleges\Sri Eshwar College of Engineering\2025\Engineering 2025.txt
# Processing: colleges\Sri Eshwar College of Engineering\2025\Innovation 2025.txt
# Processing: colleges\Sri Eshwar College of Engineering\2025\Overall 2025.txt
# Processing: colleges\Sri Eshwar College of Engineering\2025\SDG 2025.txt
# Processing: colleges\Sri Sai Ram Institute of Technology\2024\Engineering 2024.txt
# Processing: colleges\Sri Sai Ram Institute of Technology\2024\Innovation 2024.txt
# Processing: colleges\Sri Sai Ram Institute of Technology\2025\Engineering 2025.txt
# Processing: colleges\Sri Sai Ram Institute of Technology\2025\Innovation 2025.txt
# Processing: colleges\Sri Sai Ram Institute of Technology\2025\SDG 2025.txt
# Processing: colleges\Sri Venkateswara College of Engineering and Technology\2024\Engineering 2024.txt
# Processing: colleges\Sri Venkateswara College of Engineering and Technology\2024\Overall 2024.txt
# Processing: colleges\Sri Venkateswara College of Engineering and Technology\2025\Engineering 2025.txt
# Processing: colleges\Sri Venkateswara College of Engineering and Technology\2025\Overall 2025.txt
# Processing: colleges\The LNM Institute of Information Technology, Jaipur\2017\Engineering 2017.txt
# Processing: colleges\The LNM Institute of Information Technology, Jaipur\2017\Overall 2017.txt
# Processing: colleges\The LNM Institute of Information Technology, Jaipur\2018\Engineering 2018.txt
# Processing: colleges\The LNM Institute of Information Technology, Jaipur\2018\Overall 2018.txt
# Processing: colleges\The LNM Institute of Information Technology, Jaipur\2019\Engineering 2019.txt
# Processing: colleges\The LNM Institute of Information Technology, Jaipur\2019\Overall 2019.txt
# Processing: colleges\The LNM Institute of Information Technology, Jaipur\2020\Engineering 2020.txt
# Processing: colleges\The LNM Institute of Information Technology, Jaipur\2020\Overall 2020.txt
# Processing: colleges\The LNM Institute of Information Technology, Jaipur\2021\Engineering 2021.txt
# Processing: colleges\The LNM Institute of Information Technology, Jaipur\2021\Overall 2021.txt
# Processing: colleges\The LNM Institute of Information Technology, Jaipur\2022\Engineering 2022.txt
# Processing: colleges\The LNM Institute of Information Technology, Jaipur\2022\Overall 2022.txt
# Processing: colleges\The LNM Institute of Information Technology, Jaipur\2023\Engineering 2023.txt
# Processing: colleges\The LNM Institute of Information Technology, Jaipur\2023\Overall 2023.txt
# Processing: colleges\The LNM Institute of Information Technology, Jaipur\2024\Engineering 2024.txt
# Processing: colleges\The LNM Institute of Information Technology, Jaipur\2024\Innovation 2024.txt
# Processing: colleges\The LNM Institute of Information Technology, Jaipur\2024\Overall 2024.txt
# Processing: colleges\The LNM Institute of Information Technology, Jaipur\2025\Engineering 2025.txt
# Processing: colleges\The LNM Institute of Information Technology, Jaipur\2025\Innovation 2025.txt
# Processing: colleges\The LNM Institute of Information Technology, Jaipur\2025\Overall 2025.txt
# Processing: colleges\The LNM Institute of Information Technology, Jaipur\2025\SDG 2025.txt
# Processing: colleges\University of Allahabad\2024\Engineering 2024.txt
# Processing: colleges\University of Allahabad\2024\Law 2024.txt
# Processing: colleges\University of Allahabad\2024\Management 2024.txt
# Processing: colleges\University of Allahabad\2024\Overall 2024.txt
# Processing: colleges\University of Allahabad\2025\Engineering 2025.txt
# Processing: colleges\University of Allahabad\2025\Law 2025.txt
# Processing: colleges\University of Allahabad\2025\Management 2025.txt
# Processing: colleges\University of Allahabad\2025\Overall 2025.txt
# Processing: colleges\Vidya Jyothi Institute of Technology\2024\Innovation 2024.txt
# Processing: colleges\Vidya Jyothi Institute of Technology\2024\Overall 2024.txt
# Processing: colleges\Vidya Jyothi Institute of Technology\2025\Engineering 2025.txt
# Processing: colleges\Vidya Jyothi Institute of Technology\2025\Innovation 2025.txt
# Processing: colleges\Vidya Jyothi Institute of Technology\2025\Overall 2025.txt
# Processing: colleges\Vidya Jyothi Institute of Technology\2025\SDG 2025.txt
# Processing: colleges\Vignan`s Institute of Information Technology\2024\Engineering 2024.txt
# Processing: colleges\Vignan`s Institute of Information Technology\2024\Innovation 2024.txt
# Processing: colleges\Vignan`s Institute of Information Technology\2025\Engineering 2025.txt
# Processing: colleges\Vignan`s Institute of Information Technology\2025\Innovation 2025.txt
# Reports saved to: C:\Users\siddhu\Desktop\text_files (201 to 300)_processed\reports
#
# Completed!
# Files processed: 777
# Duplicates removed: 0
# Chunks created: 25301
# Search term (or 'quit'):  quit
